# %% [markdown]
# # How to properly prevent overfitting

# %% [markdown]
# 🎯 **Goals of this challenge**
# - **`Cross Validate`** a Deep Learning Model
# - Give a **`Validation Set`** to the model
# - Apply two techniques to prevent overfitting:
#     - Use the **`Early Stopping`** criterion to prevent the Neural network from over-learning / over-fitting
#     - **`Regularize`** your network
# - Analyze the **`impact of the batch size and the number of epochs`** on the training of a Neural Network

# %%
# DATA MANIPULATION
import numpy as np

# DATA VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data: the `blobs` dataset

# %%
# BLOB DATASET
from sklearn.datasets import make_blobs

# %% [markdown]
# ❓ **Question: generating a "blobs dataset"** ❓
#
# First, let's generate some data using the [`make_blob`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) function from Scikit-Learn
#
# Generate:
# * 2000 samples with 10 features each
# * There should be 8 classes of blobs (`centers` argument), with `cluster_std` equal to 7.

# %%
#Generate data 

X,y = make_blobs(n_samples= 2000, n_features= 10, centers= 8 , cluster_std= 7)
X
# Out:
# array([[  2.87156987,   0.77372048,  11.25254898, ...,   4.36940489,
#          -4.08567605,  -3.88661141],
#        [  2.50976444,  -3.82837495,  -2.16907738, ...,   1.10019878,
#         -30.32119934,  10.06453712],
#        [-10.49493915,   7.52470667,  -5.98369335, ...,  -2.20590289,
#         -15.14176709, -12.91120579],
#        ...,
#        [  5.81514794,  14.05888545,  -0.98005904, ..., -12.20931925,
#         -11.67999297,   4.19328064],
#        [-18.21197252,   5.1779813 ,  -0.43916184, ..., -17.76514139,
#         -10.83041484,   2.9109309 ],
#        [ -0.07902456,  -0.14647343,  -4.02708043, ...,  -7.44213447,
#          -1.38987635,   9.53632149]])

# %% [markdown]
# ❓ **Question: visualizing the dataset** ❓
#
# All your samples have 10 features.
# Plot one of the dimensions against another.

# %%
plt.scatter(X[:,0],X[:,1], c = y)

# %% [markdown]
# ❓ **Question: "encoding" your categorical target** ❓
#
# Use the 📚 [***to_categorical***](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical) function to convert `y` to `y_cat` which is the categorical representation of `y` with "*one-hot encoded*" columns.

# %%
from tensorflow.keras.utils import to_categorical

# %%
y[0]
# Out:
# 0

# %%
y_cat = to_categorical(y)
y_cat[0]
# Out:
# array([1., 0., 0., 0., 0., 0., 0., 0.], dtype=float32)

# %% [markdown]
# ## (1) Cross Validation in Deep Learning

# %% [markdown]
# 👩🏻‍🏫 In a previous challenge, we split the dataset into a train set and a test set at the beginning of the notebook.
#
# And then, we started to build different models which were trained on the train set and evaluated on the test set.
#
# So, at the end of the day, we used the test set every time we evaluated our models and different hyperparameters. This is normal: we train on the train set and we evaluate on the test set.
#
# However, we selected our _"best model"_ based on the score of each model. In other words, we _used_ the test set to select our best model, which is a sort of ❗️ `data-leakage` ❗️
#
# 🤔 What should I do?
#
# * A first good practice is to avoid using `random_state` or any deterministic separation between your train and test set. In that case, your test set will change every time you re-run your notebook. But this is far from being sufficient.
#
# * To compare models properly, you have to run a cross-validation, a 10-fold split for instance.
#
# 🧐 If you look at [sklearn.model_selection.cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html), this Cross Validation tool is designed for Machine Learning algorithms implemented in Scikit Learn... whereas we have been creating and using Neural Networks from Tensorflow/Keras.
#
# 🔥 Let's discover how to **Cross-Validate a Neural Network**.

# %% [markdown]
# ❓ **Question: designing a Neural Network** ❓
#
# First, write a function that generates a Neural Network with 3 layers:
#
# <u>Architecture</u>
# - an *input layer* with 25 neurons, the `relu` activation function and the appropriate `input_dim`
# - a *hidden layer* with 10 neurons and the `relu` activation function.
# - a *predictive layer* which is suited to the problem at hand (*multiclass classification*)
#
# <u>Compilation</u>
#
# The function should include a compilation method with:
# - the *categorical_crossentropy* loss,
# - the *adam* optimizer
# - the *accuracy* metrics.

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
def initialize_model():
    model = models.Sequential()
    
    model.add(layers.Dense(25, activation='relu', input_dim = 10))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(8, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# ❓ **Question: Cross-Validating the Neural Net** ❓
#
# 🧑🏻‍💻 Write a _loop_ using the [K-Fold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) function from Scikit-Learn.
#
# * ✂️ Choose 10 splits to fit your model on the train data
# * 🧪 Evaluate your model on the test data. Store the results of the evaluation into a `results` variable.
#
# _Hints_:
# * ⚖️ Do not forget to standardize your train data before fitting the neural network.
# * 👌 Also, 150 epochs should be sufficient for a first approximation
# * 🤝 As this is your first Deep Learning Cross Validation, you are guided. Uncomment the following cell and follow the steps.
# * ⏳ Notice that we added `%% time` at the beginning of this Jupyter Notebook cell to display its running time and we encourage you to do so whenever you have expensive computations.

# %%
# %%time

from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

kf = KFold(n_splits=10)
kf.get_n_splits(X)

results = []
scaler = StandardScaler()

for train_index, test_index in kf.split(X):
    # Split the data into train and test
    X_train = X[train_index]
    X_test = X[test_index]
    
    #print(f'Train Index: {train_index}')
    #print(f'X_train_shape: {X_train}')
    
    y_train= y_cat[train_index]
    y_test = y_cat[test_index]
    
    #print(f'y_train_shape: {y_train}')
    
    # Scaling your data
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.fit_transform(X_test)
    
    #print(f'X_train_scaled: {X_train_scaled}')
     
    # Initialize the model
    model = initialize_model()
    
    # Fit the model on the train data
    model.fit(X_train_scaled, y_train, validation_split= 0.3,
    epochs=150, batch_size=32, verbose=0)
    
    # Evaluate the model on the test data
    results.append(model.evaluate(X_test_scaled, y_test))
# Out:
# 7/7 [==============================] - 0s 488us/step - loss: 0.8968 - accuracy: 0.7000
# 7/7 [==============================] - 0s 501us/step - loss: 0.9109 - accuracy: 0.6600
# 7/7 [==============================] - 0s 483us/step - loss: 0.7306 - accuracy: 0.7050
# 7/7 [==============================] - 0s 516us/step - loss: 0.8154 - accuracy: 0.7300
# 7/7 [==============================] - 0s 456us/step - loss: 1.0038 - accuracy: 0.6650
# 7/7 [==============================] - 0s 522us/step - loss: 0.9245 - accuracy: 0.7050
# 7/7 [==============================] - 0s 515us/step - loss: 0.8063 - accuracy: 0.7250
# 7/7 [==============================] - 0s 489us/step - loss: 0.8644 - accuracy: 0.6650
# 7/7 [==============================] - 0s 505us/step - loss: 0.8371 - accuracy: 0.7250
# 7/7 [==============================] - 0s 507us/step - loss: 0.9467 - accuracy: 0.6450
# CPU times: user 1min 2s, sys: 15.5 s, total: 1min 18s
# Wall time: 56 s

# %%
results
# Out:
# [[0.8967909216880798, 0.699999988079071],
#  [0.9109322428703308, 0.6600000262260437],
#  [0.7305507063865662, 0.7049999833106995],
#  [0.8153825998306274, 0.7300000190734863],
#  [1.0037859678268433, 0.6650000214576721],
#  [0.9245145916938782, 0.7049999833106995],
#  [0.8062829375267029, 0.7250000238418579],
#  [0.8643616437911987, 0.6650000214576721],
#  [0.8370671272277832, 0.7250000238418579],
#  [0.9466975331306458, 0.6449999809265137]]

# %% [markdown]
# ❓ **Question: Performance of the Cross Validated Network** ❓
#
# Print the average accuracy of these 10 folds and the standard deviation of these 10 accuracy values.

# %%
average_accuracy = np.mean(results, axis = 0)[1]
average_accuracy
# Out:
# 0.6925000071525573

# %% [markdown]
# ❗ **Remarks about the computational time** ❗
#
# * 🤯 You probably encountered one of the main drawbacks of using a proper cross-validation for a Neural Network: **it takes a lot of time**! Therefore, for the rest of the Deep-Learning module, we will do ***only one split***.
#
# * 👮🏻‍♀️ But remember that this is not entirely correct and, for real-life applications and problems, you are encouraged to use a proper cross-validation technique.
#
# * 💼 In general, what practitioners do, is that they split only once, as you did. And once they get to the end of their optimization, they launch a real cross-validation at 6 PM, go home and get the final results on the next day.

# %% [markdown]
# ❓ **Question: Holdout Method** ❓
#
# For the rest of the exercise (and of the Deep Learning module), split the dataset into a train set and a test set with a 70/30% training to test data ratio.

# %%
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y_cat, test_size = 0.3)

# %% [markdown]
# ## (2) How to prevent a Neural Network from overfitting?

# %% [markdown]
# ### (2.1) Early Stopping
#
# 🚦 ***Stop the learning process before overfitting***

# %% [markdown]
# ❓ **Question: illustrating how a Neural Network can easily overfit...** ❓
#
# First things first, let's show that if we train the model for too long (for too many epochs) it will overfit the training data and will not be good at predicting on the test data.
#
# ***How can we do it without using the test data, which is strictly forbidden?***
#
# You can use a fraction of the <font color=blue>training set</font> as a <font color=green>validation set</font>.
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/lectures/deep-learning/02/validation_set.png" width=200 height=150>
#
# With Keras, you don't have to re-use the `train_test_split` method from Scikit Learn.
#
# Two options:
#
# - `validation_split` = 0.2 for example
#     - The model will take the last 20% of the observations in the training set and and use this group as the validation holdout set
#     - If you want a random train_val_split within the training set, you can also add the argument `shuffle = True` in `model.fit(...)`
#
# - `validation_data = (X_val, y_val)` if you have access to a dataset that you want to use as the validation holdout set.
#
#
#
# 👉 Let's go with the first option and `epochs = 500`.
#
# 👉 Store the performances of the model into a `history` variable.

# %%
# %%time

model = initialize_model()
history = model.fit(X_train,y_train, validation_split=0.2, epochs= 500, batch_size= 32)
# Out:
# Epoch 1/500
# 35/35 [==============================] - 0s 3ms/step - loss: 4.5401 - accuracy: 0.1929 - val_loss: 3.0550 - val_accuracy: 0.2286
# Epoch 2/500
# 35/35 [==============================] - 0s 1ms/step - loss: 2.4242 - accuracy: 0.2946 - val_loss: 2.0432 - val_accuracy: 0.3071
# Epoch 3/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.8052 - accuracy: 0.3616 - val_loss: 1.7285 - val_accuracy: 0.3464
# Epoch 4/500
# 35/35 [==============================] - 0s 990us/step - loss: 1.5542 - accuracy: 0.4330 - val_loss: 1.5318 - val_accuracy: 0.4607
# Epoch 5/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.3898 - accuracy: 0.5089 - val_loss: 1.3990 - val_accuracy: 0.5036
# Epoch 6/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.2743 - accuracy: 0.5545 - val_loss: 1.2909 - val_accuracy: 0.5464
# Epoch 7/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.1898 - accuracy: 0.5830 - val_loss: 1.2187 - val_accuracy: 0.5857
# Epoch 8/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.1255 - accuracy: 0.5973 - val_loss: 1.1647 - val_accuracy: 0.5964
# Epoch 9/500
# 35/35 [==============================] - 0s 999us/step - loss: 1.0745 - accuracy: 0.6196 - val_loss: 1.1118 - val_accuracy: 0.6036
# Epoch 10/500
# 35/35 [==============================] - 0s 1ms/step - loss: 1.0356 - accuracy: 0.6330 - val_loss: 1.0845 - val_accuracy: 0.6000
# Epoch 11/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.9958 - accuracy: 0.6464 - val_loss: 1.0501 - val_accuracy: 0.6107
# Epoch 12/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.9631 - accuracy: 0.6580 - val_loss: 1.0305 - val_accuracy: 0.6214
# Epoch 13/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.9366 - accuracy: 0.6714 - val_loss: 1.0072 - val_accuracy: 0.6321
# Epoch 14/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.9134 - accuracy: 0.6786 - val_loss: 0.9968 - val_accuracy: 0.6429
# Epoch 15/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.8932 - accuracy: 0.6804 - val_loss: 0.9841 - val_accuracy: 0.6429
# Epoch 16/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.8756 - accuracy: 0.6839 - val_loss: 0.9735 - val_accuracy: 0.6536
# Epoch 17/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.8601 - accuracy: 0.6955 - val_loss: 0.9674 - val_accuracy: 0.6536
# Epoch 18/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.8435 - accuracy: 0.6991 - val_loss: 0.9592 - val_accuracy: 0.6536
# Epoch 19/500
# 35/35 [==============================] - 0s 959us/step - loss: 0.8293 - accuracy: 0.7036 - val_loss: 0.9530 - val_accuracy: 0.6464
# Epoch 20/500
# 35/35 [==============================] - 0s 974us/step - loss: 0.8154 - accuracy: 0.7116 - val_loss: 0.9463 - val_accuracy: 0.6571
# Epoch 21/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.8054 - accuracy: 0.7089 - val_loss: 0.9470 - val_accuracy: 0.6571
# Epoch 22/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.7950 - accuracy: 0.7107 - val_loss: 0.9333 - val_accuracy: 0.6607
# Epoch 23/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.7816 - accuracy: 0.7188 - val_loss: 0.9457 - val_accuracy: 0.6679
# Epoch 24/500
# 35/35 [==============================] - 0s 966us/step - loss: 0.7740 - accuracy: 0.7170 - val_loss: 0.9311 - val_accuracy: 0.6643
# Epoch 25/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.7628 - accuracy: 0.7214 - val_loss: 0.9355 - val_accuracy: 0.6750
# Epoch 26/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.7549 - accuracy: 0.7205 - val_loss: 0.9268 - val_accuracy: 0.6750
# Epoch 27/500
# 35/35 [==============================] - 0s 966us/step - loss: 0.7493 - accuracy: 0.7196 - val_loss: 0.9414 - val_accuracy: 0.6679
# Epoch 28/500
# 35/35 [==============================] - 0s 964us/step - loss: 0.7382 - accuracy: 0.7232 - val_loss: 0.9282 - val_accuracy: 0.6821
# Epoch 29/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.7321 - accuracy: 0.7304 - val_loss: 0.9180 - val_accuracy: 0.6786
# Epoch 30/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.7253 - accuracy: 0.7384 - val_loss: 0.9170 - val_accuracy: 0.6964
# Epoch 31/500
# 35/35 [==============================] - 0s 981us/step - loss: 0.7158 - accuracy: 0.7357 - val_loss: 0.9173 - val_accuracy: 0.6893
# Epoch 32/500
# 35/35 [==============================] - 0s 974us/step - loss: 0.7108 - accuracy: 0.7348 - val_loss: 0.9097 - val_accuracy: 0.6964
# Epoch 33/500
# 35/35 [==============================] - 0s 971us/step - loss: 0.7053 - accuracy: 0.7393 - val_loss: 0.9061 - val_accuracy: 0.6964
# Epoch 34/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.6989 - accuracy: 0.7411 - val_loss: 0.9195 - val_accuracy: 0.6857
# Epoch 35/500
# 35/35 [==============================] - 0s 997us/step - loss: 0.6968 - accuracy: 0.7384 - val_loss: 0.9017 - val_accuracy: 0.6821
# Epoch 36/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6892 - accuracy: 0.7411 - val_loss: 0.9090 - val_accuracy: 0.7000
# Epoch 37/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.6823 - accuracy: 0.7464 - val_loss: 0.9091 - val_accuracy: 0.6929
# Epoch 38/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6792 - accuracy: 0.7411 - val_loss: 0.9164 - val_accuracy: 0.6929
# Epoch 39/500
# 35/35 [==============================] - 0s 968us/step - loss: 0.6721 - accuracy: 0.7509 - val_loss: 0.9004 - val_accuracy: 0.6929
# Epoch 40/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6667 - accuracy: 0.7536 - val_loss: 0.9003 - val_accuracy: 0.7000
# Epoch 41/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6621 - accuracy: 0.7580 - val_loss: 0.8965 - val_accuracy: 0.6893
# Epoch 42/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6614 - accuracy: 0.7580 - val_loss: 0.8938 - val_accuracy: 0.6964
# Epoch 43/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6572 - accuracy: 0.7536 - val_loss: 0.8910 - val_accuracy: 0.6929
# Epoch 44/500
# 35/35 [==============================] - 0s 969us/step - loss: 0.6543 - accuracy: 0.7536 - val_loss: 0.9003 - val_accuracy: 0.6857
# Epoch 45/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6550 - accuracy: 0.7500 - val_loss: 0.9069 - val_accuracy: 0.6893
# Epoch 46/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.6487 - accuracy: 0.7589 - val_loss: 0.8986 - val_accuracy: 0.7071
# Epoch 47/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6473 - accuracy: 0.7554 - val_loss: 0.9063 - val_accuracy: 0.6750
# Epoch 48/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6424 - accuracy: 0.7625 - val_loss: 0.8915 - val_accuracy: 0.7000
# Epoch 49/500
# 35/35 [==============================] - 0s 960us/step - loss: 0.6378 - accuracy: 0.7616 - val_loss: 0.9009 - val_accuracy: 0.6964
# Epoch 50/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.6365 - accuracy: 0.7607 - val_loss: 0.8921 - val_accuracy: 0.6964
# Epoch 51/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6326 - accuracy: 0.7634 - val_loss: 0.8883 - val_accuracy: 0.6857
# Epoch 52/500
# 35/35 [==============================] - 0s 974us/step - loss: 0.6310 - accuracy: 0.7607 - val_loss: 0.8905 - val_accuracy: 0.7000
# Epoch 53/500
# 35/35 [==============================] - 0s 966us/step - loss: 0.6265 - accuracy: 0.7625 - val_loss: 0.9009 - val_accuracy: 0.6857
# Epoch 54/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6254 - accuracy: 0.7625 - val_loss: 0.8999 - val_accuracy: 0.6857
# Epoch 55/500
# 35/35 [==============================] - 0s 986us/step - loss: 0.6214 - accuracy: 0.7616 - val_loss: 0.8940 - val_accuracy: 0.6786
# Epoch 56/500
# 35/35 [==============================] - 0s 972us/step - loss: 0.6177 - accuracy: 0.7652 - val_loss: 0.8882 - val_accuracy: 0.6964
# Epoch 57/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.6159 - accuracy: 0.7688 - val_loss: 0.8909 - val_accuracy: 0.6893
# Epoch 58/500
# 35/35 [==============================] - 0s 910us/step - loss: 0.6158 - accuracy: 0.7670 - val_loss: 0.8997 - val_accuracy: 0.6750
# Epoch 59/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.6126 - accuracy: 0.7696 - val_loss: 0.8947 - val_accuracy: 0.6821
# Epoch 60/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6113 - accuracy: 0.7705 - val_loss: 0.8903 - val_accuracy: 0.6857
# Epoch 61/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.6090 - accuracy: 0.7714 - val_loss: 0.9080 - val_accuracy: 0.6857
# Epoch 62/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.6085 - accuracy: 0.7670 - val_loss: 0.9081 - val_accuracy: 0.6893
# Epoch 63/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.6032 - accuracy: 0.7705 - val_loss: 0.8959 - val_accuracy: 0.6786
# Epoch 64/500
# 35/35 [==============================] - 0s 969us/step - loss: 0.6011 - accuracy: 0.7643 - val_loss: 0.8953 - val_accuracy: 0.6821
# Epoch 65/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.6059 - accuracy: 0.7705 - val_loss: 0.8856 - val_accuracy: 0.6821
# Epoch 66/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5991 - accuracy: 0.7768 - val_loss: 0.9076 - val_accuracy: 0.6786
# Epoch 67/500
# 35/35 [==============================] - 0s 976us/step - loss: 0.5974 - accuracy: 0.7777 - val_loss: 0.9075 - val_accuracy: 0.6821
# Epoch 68/500
# 35/35 [==============================] - 0s 978us/step - loss: 0.5977 - accuracy: 0.7723 - val_loss: 0.8918 - val_accuracy: 0.7000
# Epoch 69/500
# 35/35 [==============================] - 0s 972us/step - loss: 0.5916 - accuracy: 0.7723 - val_loss: 0.9096 - val_accuracy: 0.6893
# Epoch 70/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5892 - accuracy: 0.7750 - val_loss: 0.8923 - val_accuracy: 0.6857
# Epoch 71/500
# 35/35 [==============================] - 0s 971us/step - loss: 0.5887 - accuracy: 0.7821 - val_loss: 0.8997 - val_accuracy: 0.6821
# Epoch 72/500
# 35/35 [==============================] - 0s 924us/step - loss: 0.5841 - accuracy: 0.7705 - val_loss: 0.9025 - val_accuracy: 0.6821
# Epoch 73/500
# 35/35 [==============================] - 0s 973us/step - loss: 0.5802 - accuracy: 0.7750 - val_loss: 0.9071 - val_accuracy: 0.6964
# Epoch 74/500
# 35/35 [==============================] - 0s 980us/step - loss: 0.5825 - accuracy: 0.7812 - val_loss: 0.8970 - val_accuracy: 0.6893
# Epoch 75/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5815 - accuracy: 0.7795 - val_loss: 0.9099 - val_accuracy: 0.6786
# Epoch 76/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5783 - accuracy: 0.7777 - val_loss: 0.9104 - val_accuracy: 0.6857
# Epoch 77/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.5751 - accuracy: 0.7857 - val_loss: 0.9054 - val_accuracy: 0.6964
# Epoch 78/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5741 - accuracy: 0.7786 - val_loss: 0.9041 - val_accuracy: 0.6893
# Epoch 79/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.5692 - accuracy: 0.7884 - val_loss: 0.9166 - val_accuracy: 0.6857
# Epoch 80/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.5674 - accuracy: 0.7804 - val_loss: 0.9138 - val_accuracy: 0.6964
# Epoch 81/500
# 35/35 [==============================] - 0s 969us/step - loss: 0.5640 - accuracy: 0.7875 - val_loss: 0.9168 - val_accuracy: 0.6893
# Epoch 82/500
# 35/35 [==============================] - 0s 950us/step - loss: 0.5614 - accuracy: 0.7839 - val_loss: 0.9180 - val_accuracy: 0.6857
# Epoch 83/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5615 - accuracy: 0.7839 - val_loss: 0.9064 - val_accuracy: 0.6893
# Epoch 84/500
# 35/35 [==============================] - 0s 993us/step - loss: 0.5594 - accuracy: 0.7902 - val_loss: 0.9496 - val_accuracy: 0.6893
# Epoch 85/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.5557 - accuracy: 0.7920 - val_loss: 0.9124 - val_accuracy: 0.6964
# Epoch 86/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.5547 - accuracy: 0.7884 - val_loss: 0.9252 - val_accuracy: 0.6893
# Epoch 87/500
# 35/35 [==============================] - 0s 974us/step - loss: 0.5523 - accuracy: 0.7911 - val_loss: 0.9208 - val_accuracy: 0.7036
# Epoch 88/500
# 35/35 [==============================] - 0s 970us/step - loss: 0.5524 - accuracy: 0.7839 - val_loss: 0.9270 - val_accuracy: 0.7000
# Epoch 89/500
# 35/35 [==============================] - 0s 973us/step - loss: 0.5504 - accuracy: 0.7893 - val_loss: 0.9227 - val_accuracy: 0.7000
# Epoch 90/500
# 35/35 [==============================] - 0s 967us/step - loss: 0.5473 - accuracy: 0.7884 - val_loss: 0.9320 - val_accuracy: 0.7036
# Epoch 91/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.5458 - accuracy: 0.7973 - val_loss: 0.9245 - val_accuracy: 0.6964
# Epoch 92/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.5450 - accuracy: 0.7911 - val_loss: 0.9152 - val_accuracy: 0.7143
# Epoch 93/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.5405 - accuracy: 0.7875 - val_loss: 0.9342 - val_accuracy: 0.6929
# Epoch 94/500
# 35/35 [==============================] - 0s 976us/step - loss: 0.5385 - accuracy: 0.7964 - val_loss: 0.9265 - val_accuracy: 0.7000
# Epoch 95/500
# 35/35 [==============================] - 0s 958us/step - loss: 0.5368 - accuracy: 0.7902 - val_loss: 0.9348 - val_accuracy: 0.7000
# Epoch 96/500
# 35/35 [==============================] - 0s 921us/step - loss: 0.5338 - accuracy: 0.7964 - val_loss: 0.9349 - val_accuracy: 0.7107
# Epoch 97/500
# 35/35 [==============================] - 0s 965us/step - loss: 0.5339 - accuracy: 0.7911 - val_loss: 0.9318 - val_accuracy: 0.7036
# Epoch 98/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.5322 - accuracy: 0.7929 - val_loss: 0.9360 - val_accuracy: 0.6893
# Epoch 99/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5333 - accuracy: 0.7964 - val_loss: 0.9301 - val_accuracy: 0.7071
# Epoch 100/500
# 35/35 [==============================] - 0s 989us/step - loss: 0.5303 - accuracy: 0.7973 - val_loss: 0.9329 - val_accuracy: 0.7000
# Epoch 101/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5284 - accuracy: 0.7920 - val_loss: 0.9579 - val_accuracy: 0.7107
# Epoch 102/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5271 - accuracy: 0.7991 - val_loss: 0.9365 - val_accuracy: 0.7107
# Epoch 103/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.7973 - val_loss: 0.9386 - val_accuracy: 0.7143
# Epoch 104/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.5219 - accuracy: 0.7964 - val_loss: 0.9684 - val_accuracy: 0.6964
# Epoch 105/500
# 35/35 [==============================] - 0s 985us/step - loss: 0.5205 - accuracy: 0.7973 - val_loss: 0.9416 - val_accuracy: 0.7286
# Epoch 106/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.5190 - accuracy: 0.7991 - val_loss: 0.9506 - val_accuracy: 0.7071
# Epoch 107/500
# 35/35 [==============================] - 0s 951us/step - loss: 0.5181 - accuracy: 0.8009 - val_loss: 0.9587 - val_accuracy: 0.7107
# Epoch 108/500
# 35/35 [==============================] - 0s 970us/step - loss: 0.5199 - accuracy: 0.7991 - val_loss: 0.9517 - val_accuracy: 0.7107
# Epoch 109/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.5188 - accuracy: 0.8018 - val_loss: 0.9646 - val_accuracy: 0.7036
# Epoch 110/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.5160 - accuracy: 0.8027 - val_loss: 0.9710 - val_accuracy: 0.7107
# Epoch 111/500
# 35/35 [==============================] - 0s 954us/step - loss: 0.5119 - accuracy: 0.8062 - val_loss: 0.9718 - val_accuracy: 0.7000
# Epoch 112/500
# 35/35 [==============================] - 0s 940us/step - loss: 0.5104 - accuracy: 0.7991 - val_loss: 0.9767 - val_accuracy: 0.7143
# Epoch 113/500
# 35/35 [==============================] - 0s 973us/step - loss: 0.5078 - accuracy: 0.8000 - val_loss: 0.9641 - val_accuracy: 0.7071
# Epoch 114/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.5069 - accuracy: 0.8080 - val_loss: 0.9789 - val_accuracy: 0.7107
# Epoch 115/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.5070 - accuracy: 0.8027 - val_loss: 0.9675 - val_accuracy: 0.7179
# Epoch 116/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.5039 - accuracy: 0.8071 - val_loss: 0.9810 - val_accuracy: 0.7143
# Epoch 117/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.5002 - accuracy: 0.8143 - val_loss: 0.9678 - val_accuracy: 0.7143
# Epoch 118/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.4999 - accuracy: 0.8116 - val_loss: 0.9803 - val_accuracy: 0.7179
# Epoch 119/500
# 35/35 [==============================] - 0s 951us/step - loss: 0.5001 - accuracy: 0.8089 - val_loss: 0.9722 - val_accuracy: 0.7071
# Epoch 120/500
# 35/35 [==============================] - 0s 963us/step - loss: 0.5007 - accuracy: 0.8143 - val_loss: 0.9935 - val_accuracy: 0.7143
# Epoch 121/500
# 35/35 [==============================] - 0s 965us/step - loss: 0.4980 - accuracy: 0.8089 - val_loss: 0.9600 - val_accuracy: 0.7286
# Epoch 122/500
# 35/35 [==============================] - 0s 936us/step - loss: 0.4965 - accuracy: 0.8134 - val_loss: 0.9938 - val_accuracy: 0.7036
# Epoch 123/500
# 35/35 [==============================] - 0s 976us/step - loss: 0.4993 - accuracy: 0.8125 - val_loss: 0.9871 - val_accuracy: 0.7107
# Epoch 124/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4912 - accuracy: 0.8161 - val_loss: 1.0011 - val_accuracy: 0.7036
# Epoch 125/500
# 35/35 [==============================] - 0s 976us/step - loss: 0.4891 - accuracy: 0.8152 - val_loss: 0.9938 - val_accuracy: 0.7036
# Epoch 126/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.4917 - accuracy: 0.8161 - val_loss: 0.9848 - val_accuracy: 0.7179
# Epoch 127/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.4899 - accuracy: 0.8179 - val_loss: 0.9951 - val_accuracy: 0.7143
# Epoch 128/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4874 - accuracy: 0.8170 - val_loss: 0.9931 - val_accuracy: 0.7071
# Epoch 129/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4897 - accuracy: 0.8196 - val_loss: 0.9912 - val_accuracy: 0.7107
# Epoch 130/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.4864 - accuracy: 0.8170 - val_loss: 0.9834 - val_accuracy: 0.7214
# Epoch 131/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4842 - accuracy: 0.8196 - val_loss: 1.0025 - val_accuracy: 0.7000
# Epoch 132/500
# 35/35 [==============================] - 0s 971us/step - loss: 0.4852 - accuracy: 0.8107 - val_loss: 1.0042 - val_accuracy: 0.7214
# Epoch 133/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.4835 - accuracy: 0.8134 - val_loss: 1.0048 - val_accuracy: 0.7107
# Epoch 134/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.4841 - accuracy: 0.8152 - val_loss: 1.0092 - val_accuracy: 0.7107
# Epoch 135/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.4847 - accuracy: 0.8152 - val_loss: 1.0122 - val_accuracy: 0.7179
# Epoch 136/500
# 35/35 [==============================] - 0s 997us/step - loss: 0.4800 - accuracy: 0.8152 - val_loss: 0.9985 - val_accuracy: 0.7214
# Epoch 137/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.4800 - accuracy: 0.8223 - val_loss: 0.9952 - val_accuracy: 0.7214
# Epoch 138/500
# 35/35 [==============================] - 0s 941us/step - loss: 0.4767 - accuracy: 0.8161 - val_loss: 1.0032 - val_accuracy: 0.7286
# Epoch 139/500
# 35/35 [==============================] - 0s 957us/step - loss: 0.4791 - accuracy: 0.8196 - val_loss: 1.0168 - val_accuracy: 0.7036
# Epoch 140/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4721 - accuracy: 0.8196 - val_loss: 1.0030 - val_accuracy: 0.7214
# Epoch 141/500
# 35/35 [==============================] - 0s 964us/step - loss: 0.4745 - accuracy: 0.8196 - val_loss: 1.0093 - val_accuracy: 0.7107
# Epoch 142/500
# 35/35 [==============================] - 0s 972us/step - loss: 0.4726 - accuracy: 0.8250 - val_loss: 1.0098 - val_accuracy: 0.7321
# Epoch 143/500
# 35/35 [==============================] - 0s 981us/step - loss: 0.4698 - accuracy: 0.8196 - val_loss: 1.0227 - val_accuracy: 0.7143
# Epoch 144/500
# 35/35 [==============================] - 0s 936us/step - loss: 0.4661 - accuracy: 0.8295 - val_loss: 1.0423 - val_accuracy: 0.7071
# Epoch 145/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.4678 - accuracy: 0.8232 - val_loss: 1.0534 - val_accuracy: 0.7071
# Epoch 146/500
# 35/35 [==============================] - 0s 972us/step - loss: 0.4663 - accuracy: 0.8223 - val_loss: 1.0268 - val_accuracy: 0.7179
# Epoch 147/500
# 35/35 [==============================] - 0s 965us/step - loss: 0.4691 - accuracy: 0.8259 - val_loss: 1.0253 - val_accuracy: 0.7214
# Epoch 148/500
# 35/35 [==============================] - 0s 980us/step - loss: 0.4650 - accuracy: 0.8232 - val_loss: 1.0460 - val_accuracy: 0.7214
# Epoch 149/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.4609 - accuracy: 0.8304 - val_loss: 1.0252 - val_accuracy: 0.7214
# Epoch 150/500
# 35/35 [==============================] - 0s 971us/step - loss: 0.4614 - accuracy: 0.8268 - val_loss: 1.0360 - val_accuracy: 0.7214
# Epoch 151/500
# 35/35 [==============================] - 0s 981us/step - loss: 0.4611 - accuracy: 0.8232 - val_loss: 1.0398 - val_accuracy: 0.7143
# Epoch 152/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4588 - accuracy: 0.8250 - val_loss: 1.0731 - val_accuracy: 0.7071
# Epoch 153/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4570 - accuracy: 0.8339 - val_loss: 1.0588 - val_accuracy: 0.7143
# Epoch 154/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.4545 - accuracy: 0.8357 - val_loss: 1.0625 - val_accuracy: 0.7143
# Epoch 155/500
# 35/35 [==============================] - 0s 929us/step - loss: 0.4596 - accuracy: 0.8241 - val_loss: 1.0441 - val_accuracy: 0.7179
# Epoch 156/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4557 - accuracy: 0.8313 - val_loss: 1.1083 - val_accuracy: 0.7071
# Epoch 157/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.4502 - accuracy: 0.8330 - val_loss: 1.0627 - val_accuracy: 0.7143
# Epoch 158/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.4483 - accuracy: 0.8357 - val_loss: 1.1119 - val_accuracy: 0.7000
# Epoch 159/500
# 35/35 [==============================] - 0s 989us/step - loss: 0.4529 - accuracy: 0.8366 - val_loss: 1.0876 - val_accuracy: 0.7107
# Epoch 160/500
# 35/35 [==============================] - 0s 962us/step - loss: 0.4513 - accuracy: 0.8339 - val_loss: 1.1059 - val_accuracy: 0.7107
# Epoch 161/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4492 - accuracy: 0.8348 - val_loss: 1.0798 - val_accuracy: 0.7107
# Epoch 162/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4469 - accuracy: 0.8313 - val_loss: 1.0829 - val_accuracy: 0.7107
# Epoch 163/500
# 35/35 [==============================] - 0s 994us/step - loss: 0.4446 - accuracy: 0.8402 - val_loss: 1.1080 - val_accuracy: 0.7036
# Epoch 164/500
# 35/35 [==============================] - 0s 964us/step - loss: 0.4433 - accuracy: 0.8384 - val_loss: 1.1220 - val_accuracy: 0.7107
# Epoch 165/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4452 - accuracy: 0.8339 - val_loss: 1.1085 - val_accuracy: 0.7036
# Epoch 166/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.4428 - accuracy: 0.8366 - val_loss: 1.1224 - val_accuracy: 0.7071
# Epoch 167/500
# 35/35 [==============================] - 0s 974us/step - loss: 0.4432 - accuracy: 0.8313 - val_loss: 1.1180 - val_accuracy: 0.7071
# Epoch 168/500
# 35/35 [==============================] - 0s 943us/step - loss: 0.4404 - accuracy: 0.8357 - val_loss: 1.1229 - val_accuracy: 0.7143
# Epoch 169/500
# 35/35 [==============================] - 0s 943us/step - loss: 0.4407 - accuracy: 0.8393 - val_loss: 1.1319 - val_accuracy: 0.7036
# Epoch 170/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4381 - accuracy: 0.8402 - val_loss: 1.1335 - val_accuracy: 0.7036
# Epoch 171/500
# 35/35 [==============================] - 0s 957us/step - loss: 0.4342 - accuracy: 0.8348 - val_loss: 1.1426 - val_accuracy: 0.7036
# Epoch 172/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4351 - accuracy: 0.8411 - val_loss: 1.1331 - val_accuracy: 0.7036
# Epoch 173/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.4344 - accuracy: 0.8402 - val_loss: 1.1309 - val_accuracy: 0.7071
# Epoch 174/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.8438 - val_loss: 1.1562 - val_accuracy: 0.7036
# Epoch 175/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.4335 - accuracy: 0.8438 - val_loss: 1.1582 - val_accuracy: 0.6929
# Epoch 176/500
# 35/35 [==============================] - 0s 955us/step - loss: 0.4316 - accuracy: 0.8393 - val_loss: 1.1681 - val_accuracy: 0.7000
# Epoch 177/500
# 35/35 [==============================] - 0s 956us/step - loss: 0.4330 - accuracy: 0.8411 - val_loss: 1.1506 - val_accuracy: 0.6929
# Epoch 178/500
# 35/35 [==============================] - 0s 978us/step - loss: 0.4295 - accuracy: 0.8402 - val_loss: 1.1564 - val_accuracy: 0.7000
# Epoch 179/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4304 - accuracy: 0.8420 - val_loss: 1.1629 - val_accuracy: 0.7000
# Epoch 180/500
# 35/35 [==============================] - 0s 979us/step - loss: 0.4258 - accuracy: 0.8446 - val_loss: 1.1959 - val_accuracy: 0.6964
# Epoch 181/500
# 35/35 [==============================] - 0s 975us/step - loss: 0.4269 - accuracy: 0.8464 - val_loss: 1.1786 - val_accuracy: 0.7071
# Epoch 182/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4293 - accuracy: 0.8357 - val_loss: 1.1680 - val_accuracy: 0.7000
# Epoch 183/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4229 - accuracy: 0.8455 - val_loss: 1.1816 - val_accuracy: 0.6964
# Epoch 184/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4245 - accuracy: 0.8455 - val_loss: 1.1947 - val_accuracy: 0.7000
# Epoch 185/500
# 35/35 [==============================] - 0s 964us/step - loss: 0.4192 - accuracy: 0.8509 - val_loss: 1.2023 - val_accuracy: 0.7036
# Epoch 186/500
# 35/35 [==============================] - 0s 969us/step - loss: 0.4196 - accuracy: 0.8438 - val_loss: 1.1951 - val_accuracy: 0.7036
# Epoch 187/500
# 35/35 [==============================] - 0s 993us/step - loss: 0.4210 - accuracy: 0.8491 - val_loss: 1.2133 - val_accuracy: 0.6893
# Epoch 188/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4183 - accuracy: 0.8464 - val_loss: 1.1949 - val_accuracy: 0.6929
# Epoch 189/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.4190 - accuracy: 0.8509 - val_loss: 1.1850 - val_accuracy: 0.7000
# Epoch 190/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.8455 - val_loss: 1.2195 - val_accuracy: 0.7000
# Epoch 191/500
# 35/35 [==============================] - 0s 975us/step - loss: 0.4131 - accuracy: 0.8482 - val_loss: 1.2056 - val_accuracy: 0.6929
# Epoch 192/500
# 35/35 [==============================] - 0s 978us/step - loss: 0.4113 - accuracy: 0.8500 - val_loss: 1.2207 - val_accuracy: 0.6964
# Epoch 193/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4140 - accuracy: 0.8500 - val_loss: 1.2189 - val_accuracy: 0.6929
# Epoch 194/500
# 35/35 [==============================] - 0s 987us/step - loss: 0.4086 - accuracy: 0.8509 - val_loss: 1.2494 - val_accuracy: 0.6857
# Epoch 195/500
# 35/35 [==============================] - 0s 958us/step - loss: 0.4106 - accuracy: 0.8500 - val_loss: 1.2322 - val_accuracy: 0.6893
# Epoch 196/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4114 - accuracy: 0.8580 - val_loss: 1.2276 - val_accuracy: 0.6893
# Epoch 197/500
# 35/35 [==============================] - 0s 985us/step - loss: 0.4115 - accuracy: 0.8545 - val_loss: 1.2521 - val_accuracy: 0.6821
# Epoch 198/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4118 - accuracy: 0.8473 - val_loss: 1.2451 - val_accuracy: 0.6929
# Epoch 199/500
# 35/35 [==============================] - 0s 968us/step - loss: 0.4075 - accuracy: 0.8634 - val_loss: 1.2636 - val_accuracy: 0.6857
# Epoch 200/500
# 35/35 [==============================] - 0s 952us/step - loss: 0.4053 - accuracy: 0.8616 - val_loss: 1.2349 - val_accuracy: 0.6929
# Epoch 201/500
# 35/35 [==============================] - 0s 954us/step - loss: 0.4082 - accuracy: 0.8527 - val_loss: 1.2675 - val_accuracy: 0.6821
# Epoch 202/500
# 35/35 [==============================] - 0s 973us/step - loss: 0.4022 - accuracy: 0.8545 - val_loss: 1.2395 - val_accuracy: 0.6893
# Epoch 203/500
# 35/35 [==============================] - 0s 950us/step - loss: 0.4052 - accuracy: 0.8545 - val_loss: 1.2494 - val_accuracy: 0.6929
# Epoch 204/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8616 - val_loss: 1.2611 - val_accuracy: 0.6893
# Epoch 205/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4061 - accuracy: 0.8598 - val_loss: 1.2672 - val_accuracy: 0.6857
# Epoch 206/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3992 - accuracy: 0.8670 - val_loss: 1.2685 - val_accuracy: 0.6786
# Epoch 207/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8616 - val_loss: 1.2879 - val_accuracy: 0.6821
# Epoch 208/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.4068 - accuracy: 0.8536 - val_loss: 1.2913 - val_accuracy: 0.6857
# Epoch 209/500
# 35/35 [==============================] - 0s 962us/step - loss: 0.3998 - accuracy: 0.8545 - val_loss: 1.3011 - val_accuracy: 0.6893
# Epoch 210/500
# 35/35 [==============================] - 0s 956us/step - loss: 0.3973 - accuracy: 0.8580 - val_loss: 1.2905 - val_accuracy: 0.6821
# Epoch 211/500
# 35/35 [==============================] - 0s 972us/step - loss: 0.3938 - accuracy: 0.8616 - val_loss: 1.2828 - val_accuracy: 0.6964
# Epoch 212/500
# 35/35 [==============================] - 0s 978us/step - loss: 0.3969 - accuracy: 0.8562 - val_loss: 1.2984 - val_accuracy: 0.6786
# Epoch 213/500
# 35/35 [==============================] - 0s 946us/step - loss: 0.3928 - accuracy: 0.8571 - val_loss: 1.3043 - val_accuracy: 0.6893
# Epoch 214/500
# 35/35 [==============================] - 0s 943us/step - loss: 0.3949 - accuracy: 0.8634 - val_loss: 1.2908 - val_accuracy: 0.6821
# Epoch 215/500
# 35/35 [==============================] - 0s 997us/step - loss: 0.3942 - accuracy: 0.8634 - val_loss: 1.2879 - val_accuracy: 0.6821
# Epoch 216/500
# 35/35 [==============================] - 0s 994us/step - loss: 0.3917 - accuracy: 0.8625 - val_loss: 1.2974 - val_accuracy: 0.6893
# Epoch 217/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3917 - accuracy: 0.8562 - val_loss: 1.3081 - val_accuracy: 0.6786
# Epoch 218/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3917 - accuracy: 0.8652 - val_loss: 1.3146 - val_accuracy: 0.6786
# Epoch 219/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.3888 - accuracy: 0.8643 - val_loss: 1.3147 - val_accuracy: 0.6893
# Epoch 220/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.3898 - accuracy: 0.8580 - val_loss: 1.3198 - val_accuracy: 0.6857
# Epoch 221/500
# 35/35 [==============================] - 0s 962us/step - loss: 0.3904 - accuracy: 0.8625 - val_loss: 1.3184 - val_accuracy: 0.6821
# Epoch 222/500
# 35/35 [==============================] - 0s 978us/step - loss: 0.3888 - accuracy: 0.8679 - val_loss: 1.3681 - val_accuracy: 0.6750
# Epoch 223/500
# 35/35 [==============================] - 0s 978us/step - loss: 0.3836 - accuracy: 0.8670 - val_loss: 1.3499 - val_accuracy: 0.6929
# Epoch 224/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3887 - accuracy: 0.8580 - val_loss: 1.3617 - val_accuracy: 0.6821
# Epoch 225/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.3842 - accuracy: 0.8643 - val_loss: 1.3432 - val_accuracy: 0.6929
# Epoch 226/500
# 35/35 [==============================] - 0s 945us/step - loss: 0.3819 - accuracy: 0.8652 - val_loss: 1.3656 - val_accuracy: 0.6893
# Epoch 227/500
# 35/35 [==============================] - 0s 949us/step - loss: 0.3846 - accuracy: 0.8652 - val_loss: 1.3431 - val_accuracy: 0.6893
# Epoch 228/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3832 - accuracy: 0.8661 - val_loss: 1.3709 - val_accuracy: 0.6857
# Epoch 229/500
# 35/35 [==============================] - 0s 954us/step - loss: 0.3827 - accuracy: 0.8687 - val_loss: 1.3898 - val_accuracy: 0.6821
# Epoch 230/500
# 35/35 [==============================] - 0s 949us/step - loss: 0.3816 - accuracy: 0.8696 - val_loss: 1.3513 - val_accuracy: 0.6786
# Epoch 231/500
# 35/35 [==============================] - 0s 976us/step - loss: 0.3794 - accuracy: 0.8768 - val_loss: 1.3884 - val_accuracy: 0.6857
# Epoch 232/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3782 - accuracy: 0.8679 - val_loss: 1.3690 - val_accuracy: 0.6750
# Epoch 233/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.3782 - accuracy: 0.8696 - val_loss: 1.3924 - val_accuracy: 0.6893
# Epoch 234/500
# 35/35 [==============================] - 0s 974us/step - loss: 0.3799 - accuracy: 0.8705 - val_loss: 1.3998 - val_accuracy: 0.6857
# Epoch 235/500
# 35/35 [==============================] - 0s 960us/step - loss: 0.3758 - accuracy: 0.8759 - val_loss: 1.3952 - val_accuracy: 0.6750
# Epoch 236/500
# 35/35 [==============================] - 0s 980us/step - loss: 0.3748 - accuracy: 0.8732 - val_loss: 1.3947 - val_accuracy: 0.6750
# Epoch 237/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3734 - accuracy: 0.8714 - val_loss: 1.3985 - val_accuracy: 0.6821
# Epoch 238/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3710 - accuracy: 0.8786 - val_loss: 1.4159 - val_accuracy: 0.6750
# Epoch 239/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.3767 - accuracy: 0.8696 - val_loss: 1.4416 - val_accuracy: 0.6929
# Epoch 240/500
# 35/35 [==============================] - 0s 980us/step - loss: 0.3747 - accuracy: 0.8768 - val_loss: 1.3902 - val_accuracy: 0.6750
# Epoch 241/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.3724 - accuracy: 0.8723 - val_loss: 1.4230 - val_accuracy: 0.6893
# Epoch 242/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3723 - accuracy: 0.8696 - val_loss: 1.3967 - val_accuracy: 0.6750
# Epoch 243/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3719 - accuracy: 0.8732 - val_loss: 1.4208 - val_accuracy: 0.6857
# Epoch 244/500
# 35/35 [==============================] - 0s 972us/step - loss: 0.3697 - accuracy: 0.8741 - val_loss: 1.4370 - val_accuracy: 0.6786
# Epoch 245/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.3693 - accuracy: 0.8750 - val_loss: 1.4409 - val_accuracy: 0.6750
# Epoch 246/500
# 35/35 [==============================] - 0s 973us/step - loss: 0.3662 - accuracy: 0.8804 - val_loss: 1.4144 - val_accuracy: 0.6750
# Epoch 247/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.3674 - accuracy: 0.8848 - val_loss: 1.4501 - val_accuracy: 0.6821
# Epoch 248/500
# 35/35 [==============================] - 0s 916us/step - loss: 0.3683 - accuracy: 0.8732 - val_loss: 1.4310 - val_accuracy: 0.6821
# Epoch 249/500
# 35/35 [==============================] - 0s 993us/step - loss: 0.3710 - accuracy: 0.8732 - val_loss: 1.4629 - val_accuracy: 0.6786
# Epoch 250/500
# 35/35 [==============================] - 0s 963us/step - loss: 0.3681 - accuracy: 0.8759 - val_loss: 1.4578 - val_accuracy: 0.6750
# Epoch 251/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3687 - accuracy: 0.8759 - val_loss: 1.4496 - val_accuracy: 0.6750
# Epoch 252/500
# 35/35 [==============================] - 0s 952us/step - loss: 0.3694 - accuracy: 0.8714 - val_loss: 1.4527 - val_accuracy: 0.6750
# Epoch 253/500
# 35/35 [==============================] - 0s 970us/step - loss: 0.3635 - accuracy: 0.8804 - val_loss: 1.4581 - val_accuracy: 0.6821
# Epoch 254/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3675 - accuracy: 0.8696 - val_loss: 1.4936 - val_accuracy: 0.6821
# Epoch 255/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3687 - accuracy: 0.8723 - val_loss: 1.4836 - val_accuracy: 0.6750
# Epoch 256/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3650 - accuracy: 0.8848 - val_loss: 1.4761 - val_accuracy: 0.6750
# Epoch 257/500
# 35/35 [==============================] - 0s 968us/step - loss: 0.3638 - accuracy: 0.8777 - val_loss: 1.4717 - val_accuracy: 0.6786
# Epoch 258/500
# 35/35 [==============================] - 0s 994us/step - loss: 0.3661 - accuracy: 0.8813 - val_loss: 1.4972 - val_accuracy: 0.6750
# Epoch 259/500
# 35/35 [==============================] - 0s 990us/step - loss: 0.3627 - accuracy: 0.8795 - val_loss: 1.4651 - val_accuracy: 0.6679
# Epoch 260/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.3650 - accuracy: 0.8759 - val_loss: 1.4846 - val_accuracy: 0.6714
# Epoch 261/500
# 35/35 [==============================] - 0s 967us/step - loss: 0.3596 - accuracy: 0.8830 - val_loss: 1.4837 - val_accuracy: 0.6714
# Epoch 262/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3612 - accuracy: 0.8768 - val_loss: 1.4856 - val_accuracy: 0.6714
# Epoch 263/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3654 - accuracy: 0.8759 - val_loss: 1.5050 - val_accuracy: 0.6714
# Epoch 264/500
# 35/35 [==============================] - 0s 981us/step - loss: 0.3579 - accuracy: 0.8839 - val_loss: 1.4947 - val_accuracy: 0.6786
# Epoch 265/500
# 35/35 [==============================] - 0s 948us/step - loss: 0.3583 - accuracy: 0.8830 - val_loss: 1.5207 - val_accuracy: 0.6821
# Epoch 266/500
# 35/35 [==============================] - 0s 912us/step - loss: 0.3633 - accuracy: 0.8830 - val_loss: 1.5316 - val_accuracy: 0.6750
# Epoch 267/500
# 35/35 [==============================] - 0s 969us/step - loss: 0.3639 - accuracy: 0.8759 - val_loss: 1.5236 - val_accuracy: 0.6786
# Epoch 268/500
# 35/35 [==============================] - 0s 963us/step - loss: 0.3580 - accuracy: 0.8821 - val_loss: 1.5167 - val_accuracy: 0.6786
# Epoch 269/500
# 35/35 [==============================] - 0s 997us/step - loss: 0.3596 - accuracy: 0.8929 - val_loss: 1.5409 - val_accuracy: 0.6714
# Epoch 270/500
# 35/35 [==============================] - 0s 978us/step - loss: 0.3565 - accuracy: 0.8804 - val_loss: 1.5031 - val_accuracy: 0.6750
# Epoch 271/500
# 35/35 [==============================] - 0s 933us/step - loss: 0.3597 - accuracy: 0.8795 - val_loss: 1.5421 - val_accuracy: 0.6679
# Epoch 272/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.3552 - accuracy: 0.8839 - val_loss: 1.5359 - val_accuracy: 0.6750
# Epoch 273/500
# 35/35 [==============================] - 0s 935us/step - loss: 0.3551 - accuracy: 0.8893 - val_loss: 1.5334 - val_accuracy: 0.6679
# Epoch 274/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.3540 - accuracy: 0.8884 - val_loss: 1.5728 - val_accuracy: 0.6857
# Epoch 275/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3539 - accuracy: 0.8884 - val_loss: 1.5499 - val_accuracy: 0.6750
# Epoch 276/500
# 35/35 [==============================] - 0s 985us/step - loss: 0.3552 - accuracy: 0.8839 - val_loss: 1.5361 - val_accuracy: 0.6714
# Epoch 277/500
# 35/35 [==============================] - 0s 997us/step - loss: 0.3555 - accuracy: 0.8821 - val_loss: 1.5324 - val_accuracy: 0.6821
# Epoch 278/500
# 35/35 [==============================] - 0s 967us/step - loss: 0.3564 - accuracy: 0.8839 - val_loss: 1.5677 - val_accuracy: 0.6750
# Epoch 279/500
# 35/35 [==============================] - 0s 981us/step - loss: 0.3506 - accuracy: 0.8839 - val_loss: 1.5824 - val_accuracy: 0.6714
# Epoch 280/500
# 35/35 [==============================] - 0s 958us/step - loss: 0.3536 - accuracy: 0.8848 - val_loss: 1.5767 - val_accuracy: 0.6714
# Epoch 281/500
# 35/35 [==============================] - 0s 968us/step - loss: 0.3489 - accuracy: 0.8866 - val_loss: 1.5979 - val_accuracy: 0.6643
# Epoch 282/500
# 35/35 [==============================] - 0s 987us/step - loss: 0.3512 - accuracy: 0.8938 - val_loss: 1.5878 - val_accuracy: 0.6714
# Epoch 283/500
# 35/35 [==============================] - 0s 940us/step - loss: 0.3505 - accuracy: 0.8866 - val_loss: 1.6034 - val_accuracy: 0.6786
# Epoch 284/500
# 35/35 [==============================] - 0s 905us/step - loss: 0.3513 - accuracy: 0.8857 - val_loss: 1.6244 - val_accuracy: 0.6714
# Epoch 285/500
# 35/35 [==============================] - 0s 935us/step - loss: 0.3525 - accuracy: 0.8830 - val_loss: 1.5846 - val_accuracy: 0.6679
# Epoch 286/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.3518 - accuracy: 0.8866 - val_loss: 1.5804 - val_accuracy: 0.6607
# Epoch 287/500
# 35/35 [==============================] - 0s 981us/step - loss: 0.3464 - accuracy: 0.8938 - val_loss: 1.6174 - val_accuracy: 0.6714
# Epoch 288/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.3487 - accuracy: 0.8875 - val_loss: 1.6002 - val_accuracy: 0.6643
# Epoch 289/500
# 35/35 [==============================] - 0s 966us/step - loss: 0.3475 - accuracy: 0.8857 - val_loss: 1.6185 - val_accuracy: 0.6786
# Epoch 290/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.3438 - accuracy: 0.8902 - val_loss: 1.6170 - val_accuracy: 0.6679
# Epoch 291/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3490 - accuracy: 0.8911 - val_loss: 1.6303 - val_accuracy: 0.6679
# Epoch 292/500
# 35/35 [==============================] - 0s 974us/step - loss: 0.3456 - accuracy: 0.8884 - val_loss: 1.6298 - val_accuracy: 0.6714
# Epoch 293/500
# 35/35 [==============================] - 0s 976us/step - loss: 0.3456 - accuracy: 0.8875 - val_loss: 1.6281 - val_accuracy: 0.6679
# Epoch 294/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.3413 - accuracy: 0.8902 - val_loss: 1.6733 - val_accuracy: 0.6857
# Epoch 295/500
# 35/35 [==============================] - 0s 940us/step - loss: 0.3476 - accuracy: 0.8875 - val_loss: 1.6585 - val_accuracy: 0.6714
# Epoch 296/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3452 - accuracy: 0.8929 - val_loss: 1.6384 - val_accuracy: 0.6714
# Epoch 297/500
# 35/35 [==============================] - 0s 997us/step - loss: 0.3449 - accuracy: 0.8938 - val_loss: 1.6611 - val_accuracy: 0.6643
# Epoch 298/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.3440 - accuracy: 0.8920 - val_loss: 1.6311 - val_accuracy: 0.6714
# Epoch 299/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.3435 - accuracy: 0.8920 - val_loss: 1.6779 - val_accuracy: 0.6714
# Epoch 300/500
# 35/35 [==============================] - 0s 934us/step - loss: 0.3433 - accuracy: 0.8929 - val_loss: 1.6364 - val_accuracy: 0.6679
# Epoch 301/500
# 35/35 [==============================] - 0s 973us/step - loss: 0.3471 - accuracy: 0.8821 - val_loss: 1.6605 - val_accuracy: 0.6714
# Epoch 302/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.3445 - accuracy: 0.8902 - val_loss: 1.6838 - val_accuracy: 0.6821
# Epoch 303/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3433 - accuracy: 0.8839 - val_loss: 1.6758 - val_accuracy: 0.6893
# Epoch 304/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3444 - accuracy: 0.8866 - val_loss: 1.7031 - val_accuracy: 0.6750
# Epoch 305/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3422 - accuracy: 0.8938 - val_loss: 1.7128 - val_accuracy: 0.6750
# Epoch 306/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3404 - accuracy: 0.8866 - val_loss: 1.6954 - val_accuracy: 0.6786
# Epoch 307/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3394 - accuracy: 0.8946 - val_loss: 1.7281 - val_accuracy: 0.6821
# Epoch 308/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3426 - accuracy: 0.8911 - val_loss: 1.7165 - val_accuracy: 0.6786
# Epoch 309/500
# 35/35 [==============================] - 0s 999us/step - loss: 0.3427 - accuracy: 0.8946 - val_loss: 1.7070 - val_accuracy: 0.6750
# Epoch 310/500
# 35/35 [==============================] - 0s 958us/step - loss: 0.3387 - accuracy: 0.8955 - val_loss: 1.6986 - val_accuracy: 0.6714
# Epoch 311/500
# 35/35 [==============================] - 0s 947us/step - loss: 0.3411 - accuracy: 0.8893 - val_loss: 1.7039 - val_accuracy: 0.6571
# Epoch 312/500
# 35/35 [==============================] - 0s 948us/step - loss: 0.3371 - accuracy: 0.8946 - val_loss: 1.6965 - val_accuracy: 0.6536
# Epoch 313/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.3414 - accuracy: 0.8902 - val_loss: 1.7483 - val_accuracy: 0.6893
# Epoch 314/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3389 - accuracy: 0.8893 - val_loss: 1.7093 - val_accuracy: 0.6714
# Epoch 315/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.3378 - accuracy: 0.8875 - val_loss: 1.7572 - val_accuracy: 0.6714
# Epoch 316/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3353 - accuracy: 0.8946 - val_loss: 1.7522 - val_accuracy: 0.6714
# Epoch 317/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3340 - accuracy: 0.8929 - val_loss: 1.7305 - val_accuracy: 0.6679
# Epoch 318/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3363 - accuracy: 0.8955 - val_loss: 1.7604 - val_accuracy: 0.6679
# Epoch 319/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3351 - accuracy: 0.8955 - val_loss: 1.7690 - val_accuracy: 0.6643
# Epoch 320/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3344 - accuracy: 0.8884 - val_loss: 1.7409 - val_accuracy: 0.6679
# Epoch 321/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3347 - accuracy: 0.8955 - val_loss: 1.7600 - val_accuracy: 0.6571
# Epoch 322/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3337 - accuracy: 0.8938 - val_loss: 1.7573 - val_accuracy: 0.6607
# Epoch 323/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3390 - accuracy: 0.8902 - val_loss: 1.7528 - val_accuracy: 0.6536
# Epoch 324/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3335 - accuracy: 0.8929 - val_loss: 1.7835 - val_accuracy: 0.6679
# Epoch 325/500
# 35/35 [==============================] - 0s 968us/step - loss: 0.3342 - accuracy: 0.9018 - val_loss: 1.7787 - val_accuracy: 0.6679
# Epoch 326/500
# 35/35 [==============================] - 0s 970us/step - loss: 0.3297 - accuracy: 0.8973 - val_loss: 1.7398 - val_accuracy: 0.6679
# Epoch 327/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.3334 - accuracy: 0.8955 - val_loss: 1.7800 - val_accuracy: 0.6679
# Epoch 328/500
# 35/35 [==============================] - 0s 993us/step - loss: 0.3315 - accuracy: 0.8964 - val_loss: 1.7990 - val_accuracy: 0.6714
# Epoch 329/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3312 - accuracy: 0.8991 - val_loss: 1.8111 - val_accuracy: 0.6714
# Epoch 330/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.3281 - accuracy: 0.8982 - val_loss: 1.8019 - val_accuracy: 0.6714
# Epoch 331/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3305 - accuracy: 0.8955 - val_loss: 1.8012 - val_accuracy: 0.6714
# Epoch 332/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.3300 - accuracy: 0.8964 - val_loss: 1.8526 - val_accuracy: 0.6679
# Epoch 333/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3349 - accuracy: 0.8938 - val_loss: 1.8103 - val_accuracy: 0.6607
# Epoch 334/500
# ...
# Epoch 391/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.3110 - accuracy: 0.9027 - val_loss: 2.0546 - val_accuracy: 0.6607
# Epoch 392/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.3108 - accuracy: 0.9000 - val_loss: 2.0280 - val_accuracy: 0.6750
# Epoch 393/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.3103 - accuracy: 0.9080 - val_loss: 2.0498 - val_accuracy: 0.6714
# Epoch 394/500
# 35/35 [==============================] - 0s 964us/step - loss: 0.3094 - accuracy: 0.9036 - val_loss: 2.0613 - val_accuracy: 0.6714
# Epoch 395/500
# 35/35 [==============================] - 0s 924us/step - loss: 0.3162 - accuracy: 0.8938 - val_loss: 2.0330 - val_accuracy: 0.6750
# Epoch 396/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.3103 - accuracy: 0.9027 - val_loss: 2.0156 - val_accuracy: 0.6679
# Epoch 397/500
# 35/35 [==============================] - 0s 976us/step - loss: 0.3128 - accuracy: 0.8982 - val_loss: 2.0572 - val_accuracy: 0.6679
# Epoch 398/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.3087 - accuracy: 0.9000 - val_loss: 2.0459 - val_accuracy: 0.6750
# Epoch 399/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.3076 - accuracy: 0.9027 - val_loss: 2.0450 - val_accuracy: 0.6786
# Epoch 400/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3083 - accuracy: 0.8991 - val_loss: 2.0906 - val_accuracy: 0.6571
# Epoch 401/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3084 - accuracy: 0.9036 - val_loss: 2.0371 - val_accuracy: 0.6714
# Epoch 402/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.3089 - accuracy: 0.8982 - val_loss: 2.0625 - val_accuracy: 0.6643
# Epoch 403/500
# 35/35 [==============================] - 0s 941us/step - loss: 0.3091 - accuracy: 0.9000 - val_loss: 2.0640 - val_accuracy: 0.6786
# Epoch 404/500
# 35/35 [==============================] - 0s 951us/step - loss: 0.3066 - accuracy: 0.9009 - val_loss: 2.0747 - val_accuracy: 0.6714
# Epoch 405/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.3072 - accuracy: 0.8964 - val_loss: 2.1000 - val_accuracy: 0.6714
# Epoch 406/500
# 35/35 [==============================] - 0s 994us/step - loss: 0.3082 - accuracy: 0.9009 - val_loss: 2.0748 - val_accuracy: 0.6607
# Epoch 407/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.3051 - accuracy: 0.8973 - val_loss: 2.0973 - val_accuracy: 0.6750
# Epoch 408/500
# 35/35 [==============================] - 0s 971us/step - loss: 0.3088 - accuracy: 0.9009 - val_loss: 2.0801 - val_accuracy: 0.6786
# Epoch 409/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.3072 - accuracy: 0.9009 - val_loss: 2.0937 - val_accuracy: 0.6679
# Epoch 410/500
# 35/35 [==============================] - 0s 952us/step - loss: 0.3113 - accuracy: 0.8991 - val_loss: 2.0920 - val_accuracy: 0.6679
# Epoch 411/500
# 35/35 [==============================] - 0s 911us/step - loss: 0.3110 - accuracy: 0.9027 - val_loss: 2.0851 - val_accuracy: 0.6714
# Epoch 412/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3143 - accuracy: 0.8929 - val_loss: 2.0977 - val_accuracy: 0.6821
# Epoch 413/500
# 35/35 [==============================] - 0s 972us/step - loss: 0.3059 - accuracy: 0.8973 - val_loss: 2.0948 - val_accuracy: 0.6679
# Epoch 414/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3048 - accuracy: 0.9062 - val_loss: 2.1297 - val_accuracy: 0.6679
# Epoch 415/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3043 - accuracy: 0.9054 - val_loss: 2.1083 - val_accuracy: 0.6750
# Epoch 416/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.3066 - accuracy: 0.9036 - val_loss: 2.1320 - val_accuracy: 0.6571
# Epoch 417/500
# 35/35 [==============================] - 0s 988us/step - loss: 0.3042 - accuracy: 0.9036 - val_loss: 2.1326 - val_accuracy: 0.6679
# Epoch 418/500
# 35/35 [==============================] - 0s 996us/step - loss: 0.3073 - accuracy: 0.9027 - val_loss: 2.1535 - val_accuracy: 0.6714
# Epoch 419/500
# 35/35 [==============================] - 0s 971us/step - loss: 0.3045 - accuracy: 0.9054 - val_loss: 2.1411 - val_accuracy: 0.6714
# Epoch 420/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3091 - accuracy: 0.8911 - val_loss: 2.1324 - val_accuracy: 0.6679
# Epoch 421/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.3133 - accuracy: 0.9000 - val_loss: 2.1209 - val_accuracy: 0.6893
# Epoch 422/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3070 - accuracy: 0.9009 - val_loss: 2.1255 - val_accuracy: 0.6679
# Epoch 423/500
# 35/35 [==============================] - 0s 967us/step - loss: 0.3053 - accuracy: 0.9071 - val_loss: 2.1556 - val_accuracy: 0.6821
# Epoch 424/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3038 - accuracy: 0.9045 - val_loss: 2.1513 - val_accuracy: 0.6750
# Epoch 425/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3028 - accuracy: 0.8982 - val_loss: 2.1546 - val_accuracy: 0.6821
# Epoch 426/500
# 35/35 [==============================] - 0s 950us/step - loss: 0.3017 - accuracy: 0.9009 - val_loss: 2.1342 - val_accuracy: 0.6786
# Epoch 427/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.2998 - accuracy: 0.9062 - val_loss: 2.2136 - val_accuracy: 0.6714
# Epoch 428/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.3044 - accuracy: 0.8982 - val_loss: 2.1926 - val_accuracy: 0.6607
# Epoch 429/500
# 35/35 [==============================] - 0s 958us/step - loss: 0.3045 - accuracy: 0.9027 - val_loss: 2.1160 - val_accuracy: 0.6821
# Epoch 430/500
# 35/35 [==============================] - 0s 931us/step - loss: 0.3020 - accuracy: 0.9027 - val_loss: 2.1659 - val_accuracy: 0.6786
# Epoch 431/500
# 35/35 [==============================] - 0s 983us/step - loss: 0.3029 - accuracy: 0.9027 - val_loss: 2.1660 - val_accuracy: 0.6786
# Epoch 432/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3017 - accuracy: 0.9062 - val_loss: 2.1921 - val_accuracy: 0.6714
# Epoch 433/500
# 35/35 [==============================] - 0s 968us/step - loss: 0.3008 - accuracy: 0.9098 - val_loss: 2.1549 - val_accuracy: 0.6786
# Epoch 434/500
# 35/35 [==============================] - 0s 981us/step - loss: 0.3028 - accuracy: 0.9018 - val_loss: 2.2102 - val_accuracy: 0.6643
# Epoch 435/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.3001 - accuracy: 0.9009 - val_loss: 2.2176 - val_accuracy: 0.6857
# Epoch 436/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3015 - accuracy: 0.9018 - val_loss: 2.1534 - val_accuracy: 0.6821
# Epoch 437/500
# 35/35 [==============================] - 0s 936us/step - loss: 0.3007 - accuracy: 0.9054 - val_loss: 2.2003 - val_accuracy: 0.6714
# Epoch 438/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.3007 - accuracy: 0.9027 - val_loss: 2.1714 - val_accuracy: 0.6857
# Epoch 439/500
# 35/35 [==============================] - 0s 997us/step - loss: 0.3010 - accuracy: 0.9018 - val_loss: 2.2039 - val_accuracy: 0.6821
# Epoch 440/500
# 35/35 [==============================] - 0s 963us/step - loss: 0.2997 - accuracy: 0.9000 - val_loss: 2.1948 - val_accuracy: 0.6821
# Epoch 441/500
# 35/35 [==============================] - 0s 951us/step - loss: 0.3003 - accuracy: 0.9045 - val_loss: 2.2055 - val_accuracy: 0.6857
# Epoch 442/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.2993 - accuracy: 0.9045 - val_loss: 2.2465 - val_accuracy: 0.6643
# Epoch 443/500
# 35/35 [==============================] - 0s 956us/step - loss: 0.3047 - accuracy: 0.9080 - val_loss: 2.2037 - val_accuracy: 0.6714
# Epoch 444/500
# 35/35 [==============================] - 0s 953us/step - loss: 0.3048 - accuracy: 0.8964 - val_loss: 2.1572 - val_accuracy: 0.6714
# Epoch 445/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3032 - accuracy: 0.9000 - val_loss: 2.2465 - val_accuracy: 0.6786
# Epoch 446/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3057 - accuracy: 0.9000 - val_loss: 2.2433 - val_accuracy: 0.6679
# Epoch 447/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2951 - accuracy: 0.9062 - val_loss: 2.2420 - val_accuracy: 0.6679
# Epoch 448/500
# 35/35 [==============================] - 0s 989us/step - loss: 0.2972 - accuracy: 0.9036 - val_loss: 2.2161 - val_accuracy: 0.6821
# Epoch 449/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3011 - accuracy: 0.9009 - val_loss: 2.2280 - val_accuracy: 0.6821
# Epoch 450/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.2956 - accuracy: 0.9054 - val_loss: 2.2321 - val_accuracy: 0.6714
# Epoch 451/500
# 35/35 [==============================] - 0s 991us/step - loss: 0.2970 - accuracy: 0.9071 - val_loss: 2.2360 - val_accuracy: 0.6786
# Epoch 452/500
# 35/35 [==============================] - 0s 966us/step - loss: 0.2953 - accuracy: 0.9071 - val_loss: 2.2493 - val_accuracy: 0.6679
# Epoch 453/500
# 35/35 [==============================] - 0s 939us/step - loss: 0.2977 - accuracy: 0.9036 - val_loss: 2.2493 - val_accuracy: 0.6714
# Epoch 454/500
# 35/35 [==============================] - 0s 949us/step - loss: 0.2971 - accuracy: 0.9080 - val_loss: 2.2352 - val_accuracy: 0.6786
# Epoch 455/500
# 35/35 [==============================] - 0s 979us/step - loss: 0.2948 - accuracy: 0.9107 - val_loss: 2.2462 - val_accuracy: 0.6821
# Epoch 456/500
# 35/35 [==============================] - 0s 994us/step - loss: 0.2972 - accuracy: 0.9071 - val_loss: 2.2691 - val_accuracy: 0.6679
# Epoch 457/500
# 35/35 [==============================] - 0s 986us/step - loss: 0.2932 - accuracy: 0.9062 - val_loss: 2.2430 - val_accuracy: 0.6750
# Epoch 458/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2975 - accuracy: 0.9054 - val_loss: 2.2318 - val_accuracy: 0.6750
# Epoch 459/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2967 - accuracy: 0.9054 - val_loss: 2.2455 - val_accuracy: 0.6679
# Epoch 460/500
# 35/35 [==============================] - 0s 981us/step - loss: 0.2939 - accuracy: 0.9089 - val_loss: 2.3080 - val_accuracy: 0.6643
# Epoch 461/500
# 35/35 [==============================] - 0s 992us/step - loss: 0.2916 - accuracy: 0.9089 - val_loss: 2.2705 - val_accuracy: 0.6643
# Epoch 462/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.2930 - accuracy: 0.9054 - val_loss: 2.2837 - val_accuracy: 0.6643
# Epoch 463/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2960 - accuracy: 0.9071 - val_loss: 2.3122 - val_accuracy: 0.6714
# Epoch 464/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2937 - accuracy: 0.9071 - val_loss: 2.2779 - val_accuracy: 0.6821
# Epoch 465/500
# 35/35 [==============================] - 0s 995us/step - loss: 0.2908 - accuracy: 0.9089 - val_loss: 2.3172 - val_accuracy: 0.6536
# Epoch 466/500
# 35/35 [==============================] - 0s 965us/step - loss: 0.2930 - accuracy: 0.9054 - val_loss: 2.2788 - val_accuracy: 0.6643
# Epoch 467/500
# 35/35 [==============================] - 0s 978us/step - loss: 0.2913 - accuracy: 0.9062 - val_loss: 2.2796 - val_accuracy: 0.6714
# Epoch 468/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2946 - accuracy: 0.9116 - val_loss: 2.2999 - val_accuracy: 0.6750
# Epoch 469/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2940 - accuracy: 0.9036 - val_loss: 2.2958 - val_accuracy: 0.6679
# Epoch 470/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2950 - accuracy: 0.9062 - val_loss: 2.3056 - val_accuracy: 0.6536
# Epoch 471/500
# 35/35 [==============================] - 0s 994us/step - loss: 0.2914 - accuracy: 0.9054 - val_loss: 2.3110 - val_accuracy: 0.6643
# Epoch 472/500
# 35/35 [==============================] - 0s 944us/step - loss: 0.2916 - accuracy: 0.9054 - val_loss: 2.2933 - val_accuracy: 0.6786
# Epoch 473/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.2906 - accuracy: 0.9080 - val_loss: 2.2697 - val_accuracy: 0.6786
# Epoch 474/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2906 - accuracy: 0.9036 - val_loss: 2.3362 - val_accuracy: 0.6750
# Epoch 475/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2951 - accuracy: 0.9054 - val_loss: 2.2649 - val_accuracy: 0.6750
# Epoch 476/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2942 - accuracy: 0.9045 - val_loss: 2.3477 - val_accuracy: 0.6679
# Epoch 477/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2936 - accuracy: 0.9009 - val_loss: 2.3112 - val_accuracy: 0.6750
# Epoch 478/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2901 - accuracy: 0.9161 - val_loss: 2.3900 - val_accuracy: 0.6571
# Epoch 479/500
# 35/35 [==============================] - 0s 998us/step - loss: 0.2964 - accuracy: 0.9009 - val_loss: 2.3136 - val_accuracy: 0.6679
# Epoch 480/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2948 - accuracy: 0.9045 - val_loss: 2.3309 - val_accuracy: 0.6750
# Epoch 481/500
# 35/35 [==============================] - 0s 975us/step - loss: 0.2941 - accuracy: 0.8964 - val_loss: 2.3726 - val_accuracy: 0.6500
# Epoch 482/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2929 - accuracy: 0.9045 - val_loss: 2.3477 - val_accuracy: 0.6536
# Epoch 483/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2876 - accuracy: 0.9089 - val_loss: 2.3272 - val_accuracy: 0.6714
# Epoch 484/500
# 35/35 [==============================] - 0s 979us/step - loss: 0.2896 - accuracy: 0.9071 - val_loss: 2.3756 - val_accuracy: 0.6679
# Epoch 485/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2898 - accuracy: 0.9089 - val_loss: 2.3798 - val_accuracy: 0.6714
# Epoch 486/500
# 35/35 [==============================] - 0s 940us/step - loss: 0.2894 - accuracy: 0.9125 - val_loss: 2.4000 - val_accuracy: 0.6750
# Epoch 487/500
# 35/35 [==============================] - 0s 961us/step - loss: 0.2876 - accuracy: 0.9045 - val_loss: 2.3567 - val_accuracy: 0.6679
# Epoch 488/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2894 - accuracy: 0.9107 - val_loss: 2.3786 - val_accuracy: 0.6679
# Epoch 489/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2852 - accuracy: 0.9080 - val_loss: 2.4260 - val_accuracy: 0.6571
# Epoch 490/500
# 35/35 [==============================] - 0s 964us/step - loss: 0.2909 - accuracy: 0.9054 - val_loss: 2.2915 - val_accuracy: 0.6536
# Epoch 491/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2938 - accuracy: 0.9054 - val_loss: 2.4602 - val_accuracy: 0.6607
# Epoch 492/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2865 - accuracy: 0.9071 - val_loss: 2.3533 - val_accuracy: 0.6643
# Epoch 493/500
# 35/35 [==============================] - 0s 1000us/step - loss: 0.2892 - accuracy: 0.9054 - val_loss: 2.3363 - val_accuracy: 0.6500
# Epoch 494/500
# 35/35 [==============================] - 0s 966us/step - loss: 0.2895 - accuracy: 0.9054 - val_loss: 2.4243 - val_accuracy: 0.6464
# Epoch 495/500
# 35/35 [==============================] - 0s 977us/step - loss: 0.2892 - accuracy: 0.9080 - val_loss: 2.3990 - val_accuracy: 0.6536
# Epoch 496/500
# 35/35 [==============================] - 0s 982us/step - loss: 0.2865 - accuracy: 0.9054 - val_loss: 2.4286 - val_accuracy: 0.6607
# Epoch 497/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2860 - accuracy: 0.9098 - val_loss: 2.4118 - val_accuracy: 0.6679
# Epoch 498/500
# 35/35 [==============================] - 0s 933us/step - loss: 0.2916 - accuracy: 0.9080 - val_loss: 2.4327 - val_accuracy: 0.6536
# Epoch 499/500
# 35/35 [==============================] - 0s 984us/step - loss: 0.2879 - accuracy: 0.9062 - val_loss: 2.3912 - val_accuracy: 0.6464
# Epoch 500/500
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2874 - accuracy: 0.9045 - val_loss: 2.4711 - val_accuracy: 0.6536
# CPU times: user 19.8 s, sys: 4.53 s, total: 24.3 s
# Wall time: 18.2 s

# %% [markdown]
# ❓ **Question: your Neural Network's performance** ❓
#
# Evaluate the model on the test set and print the accuracy.

# %%
model.evaluate(X_test, y_test)
# Out:
# 19/19 [==============================] - 0s 454us/step - loss: 2.2728 - accuracy: 0.6217
# [2.2728381156921387, 0.621666669845581]

# %% [markdown]
# ❓ **Question: Learnings about number of epochs** ❓
#
# Plot the history of the model with `plot_loss_accuracy` function that we coded for you.
#
# What do you observe?

# %%
def plot_loss_accuracy(history, title=None):
    fig, ax = plt.subplots(1,2, figsize=(20,7))
    
    # --- LOSS --- 
    
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].set_title('Model loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylim((0,3))
    ax[0].legend(['Train', 'Test'], loc='best')
    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)
    
    # --- ACCURACY
    
    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])
    ax[1].set_title('Model Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='best')
    ax[1].set_ylim((0,1))
    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)
    
    if title:
        fig.suptitle(title)

# %%
plot_loss_accuracy(history, title= 'With 20% validation set')

# %% [markdown]
# 👩🏻‍🏫 We clearly see that ***the number of epochs we choose has a strong influence on the final results***:
#
# * **INSUFFICIENT NUMBER OF EPOCHS $\implies$ UNDERFITTING**:
#     * The algorithm is not optimal as its ***loss function has not converged yet***,
#     * i.e. it hasn't learned enough from the training data.
# * **TOO MANY EPOCHS** $\implies$ **OVERFITTING**:
#     * Our neural network has ***learned too much from the training data***, even its noisy information...
#     * and the algorithm ***does not generalize well on test data***.
#
# 🚦 Basically, what we want is to do is ***stop the algorithm when the test loss is minimal*** (or when the test metrics is maximal).

# %% [markdown]
# ---
#
# 🧑🏻‍🏫 Let's introduce the **`Early Stopping`** criterion.
#
# The Early Stopping criterion is a way to ***automatically stop training of the algorithm*** before reaching the number of epochs that was originally set.
#
# 🕵🏻‍♂️ *How does it work?*
#
# Basically, the model will ***pay attention to the <font color=green>loss of the validation set</font>***. If <font color=green>it</font> starts increasing again 📈 while the <font color=blue>loss of the training set</font> keeps decreasing 📉, it is a good sign that the model is overfitting and the training should be stopped!
#
#
# <img src="validation_set.png" alt="Validation set" width=250 height=200/>

# %% [markdown]
# ---
#
# ❓ **Question: Observing the Early Stopping criterion** ❓
#
# Run the following code and plot the history.

# %%
# %%time

from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping()

model = initialize_model()

# Fit the model on the train data
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 500,
                    batch_size = 16, 
                    verbose = 1, 
                    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
                   )
# Out:
# Epoch 1/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.2656 - accuracy: 0.1839 - val_loss: 2.9646 - val_accuracy: 0.2043
# Epoch 2/500
# 62/62 [==============================] - 0s 906us/step - loss: 2.4042 - accuracy: 0.2646 - val_loss: 2.0984 - val_accuracy: 0.3040
# CPU times: user 456 ms, sys: 58.2 ms, total: 514 ms
# Wall time: 430 ms

# %% [markdown]
# ❓ **Question: Evaluate this model that was stopped earlier** ❓
#
# _(Also look at the historical losses)_

# %%
model.evaluate(X_test, y_test)
# Out:
# 19/19 [==============================] - 0s 517us/step - loss: 2.0459 - accuracy: 0.2833
# [2.0458977222442627, 0.28333333134651184]

# %%
plot_loss_accuracy(history, title='With Early Stopping')

# %% [markdown]
# ❗ **The problem with a strict Early Stopping** ❗
#
# * The problem, with this type of approach, is that as soon as the loss of the validation set increases, the model stops.
#
# * However, as a neural network's convergence is stochastic, The loss may slightly increase before decreasing again.
#
# ✅ The `EarlyStopping` criterion has a **`patience`** keyword that ***defines how many consecutive epochs without any loss decrease*** are allowed in the validation set before we stop the training procedure.

# %% [markdown]
# ❓ **Question: Early Stopping with patience** ❓
#
# Use the `EarlyStopping` criterion with a patience of 30 epochs, plot the results and print the accuracy on the test set

# %%
es = EarlyStopping(patience=30)

model = initialize_model()

history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 500,
                    batch_size = 16, 
                    verbose = 1, 
                    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
                   )
# Out:
# Epoch 1/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.4914 - accuracy: 0.1716 - val_loss: 2.3070 - val_accuracy: 0.2518
# Epoch 2/500
# 62/62 [==============================] - 0s 940us/step - loss: 1.8869 - accuracy: 0.3687 - val_loss: 1.6193 - val_accuracy: 0.4489
# Epoch 3/500
# 62/62 [==============================] - 0s 967us/step - loss: 1.4598 - accuracy: 0.5026 - val_loss: 1.3688 - val_accuracy: 0.5368
# Epoch 4/500
# 62/62 [==============================] - 0s 977us/step - loss: 1.2564 - accuracy: 0.5638 - val_loss: 1.2242 - val_accuracy: 0.5938
# Epoch 5/500
# 62/62 [==============================] - 0s 955us/step - loss: 1.1161 - accuracy: 0.6006 - val_loss: 1.1293 - val_accuracy: 0.6247
# Epoch 6/500
# 62/62 [==============================] - 0s 927us/step - loss: 1.0107 - accuracy: 0.6323 - val_loss: 1.0673 - val_accuracy: 0.6508
# Epoch 7/500
# 62/62 [==============================] - 0s 970us/step - loss: 0.9471 - accuracy: 0.6466 - val_loss: 1.0271 - val_accuracy: 0.6603
# Epoch 8/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.8846 - accuracy: 0.6639 - val_loss: 0.9984 - val_accuracy: 0.6722
# Epoch 9/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.8468 - accuracy: 0.6793 - val_loss: 0.9699 - val_accuracy: 0.6770
# Epoch 10/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.8155 - accuracy: 0.6895 - val_loss: 0.9541 - val_accuracy: 0.6960
# Epoch 11/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.7925 - accuracy: 0.7038 - val_loss: 0.9403 - val_accuracy: 0.6912
# Epoch 12/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.7749 - accuracy: 0.7058 - val_loss: 0.9380 - val_accuracy: 0.6960
# Epoch 13/500
# 62/62 [==============================] - 0s 939us/step - loss: 0.7560 - accuracy: 0.7273 - val_loss: 0.9252 - val_accuracy: 0.6983
# Epoch 14/500
# 62/62 [==============================] - 0s 950us/step - loss: 0.7355 - accuracy: 0.7252 - val_loss: 0.9254 - val_accuracy: 0.7078
# Epoch 15/500
# 62/62 [==============================] - 0s 985us/step - loss: 0.7223 - accuracy: 0.7344 - val_loss: 0.9217 - val_accuracy: 0.7031
# Epoch 16/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.7092 - accuracy: 0.7375 - val_loss: 0.9241 - val_accuracy: 0.6936
# Epoch 17/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.7006 - accuracy: 0.7406 - val_loss: 0.9225 - val_accuracy: 0.7031
# Epoch 18/500
# 62/62 [==============================] - 0s 981us/step - loss: 0.6866 - accuracy: 0.7487 - val_loss: 0.9124 - val_accuracy: 0.7007
# Epoch 19/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6737 - accuracy: 0.7518 - val_loss: 0.9122 - val_accuracy: 0.7055
# Epoch 20/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6669 - accuracy: 0.7487 - val_loss: 0.9191 - val_accuracy: 0.7055
# Epoch 21/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6599 - accuracy: 0.7579 - val_loss: 0.9132 - val_accuracy: 0.7078
# Epoch 22/500
# 62/62 [==============================] - 0s 994us/step - loss: 0.6459 - accuracy: 0.7589 - val_loss: 0.9361 - val_accuracy: 0.7055
# Epoch 23/500
# 62/62 [==============================] - 0s 925us/step - loss: 0.6461 - accuracy: 0.7620 - val_loss: 0.9350 - val_accuracy: 0.7007
# Epoch 24/500
# 62/62 [==============================] - 0s 868us/step - loss: 0.6399 - accuracy: 0.7651 - val_loss: 0.9247 - val_accuracy: 0.7031
# Epoch 25/500
# 62/62 [==============================] - 0s 926us/step - loss: 0.6298 - accuracy: 0.7712 - val_loss: 0.9274 - val_accuracy: 0.7078
# Epoch 26/500
# 62/62 [==============================] - 0s 980us/step - loss: 0.6236 - accuracy: 0.7763 - val_loss: 0.9249 - val_accuracy: 0.7055
# Epoch 27/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6205 - accuracy: 0.7661 - val_loss: 0.9244 - val_accuracy: 0.7078
# Epoch 28/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6138 - accuracy: 0.7661 - val_loss: 0.9361 - val_accuracy: 0.7007
# Epoch 29/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6072 - accuracy: 0.7753 - val_loss: 0.9237 - val_accuracy: 0.7031
# Epoch 30/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6035 - accuracy: 0.7814 - val_loss: 0.9335 - val_accuracy: 0.7126
# Epoch 31/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5959 - accuracy: 0.7814 - val_loss: 0.9264 - val_accuracy: 0.7031
# Epoch 32/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5961 - accuracy: 0.7814 - val_loss: 0.9312 - val_accuracy: 0.7150
# Epoch 33/500
# 62/62 [==============================] - 0s 973us/step - loss: 0.5893 - accuracy: 0.7773 - val_loss: 0.9336 - val_accuracy: 0.7126
# Epoch 34/500
# 62/62 [==============================] - 0s 919us/step - loss: 0.5869 - accuracy: 0.7804 - val_loss: 0.9246 - val_accuracy: 0.7150
# Epoch 35/500
# 62/62 [==============================] - 0s 899us/step - loss: 0.5834 - accuracy: 0.7814 - val_loss: 0.9346 - val_accuracy: 0.7055
# Epoch 36/500
# 62/62 [==============================] - 0s 873us/step - loss: 0.5733 - accuracy: 0.7824 - val_loss: 0.9319 - val_accuracy: 0.7007
# Epoch 37/500
# 62/62 [==============================] - 0s 875us/step - loss: 0.5735 - accuracy: 0.7814 - val_loss: 0.9352 - val_accuracy: 0.7055
# Epoch 38/500
# 62/62 [==============================] - 0s 939us/step - loss: 0.5669 - accuracy: 0.7824 - val_loss: 0.9435 - val_accuracy: 0.6960
# Epoch 39/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5663 - accuracy: 0.7926 - val_loss: 0.9412 - val_accuracy: 0.6936
# Epoch 40/500
# 62/62 [==============================] - 0s 982us/step - loss: 0.5624 - accuracy: 0.7957 - val_loss: 0.9421 - val_accuracy: 0.6912
# Epoch 41/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5581 - accuracy: 0.8029 - val_loss: 0.9575 - val_accuracy: 0.6936
# Epoch 42/500
# 62/62 [==============================] - 0s 892us/step - loss: 0.5521 - accuracy: 0.7916 - val_loss: 0.9594 - val_accuracy: 0.6936
# Epoch 43/500
# 62/62 [==============================] - 0s 878us/step - loss: 0.5466 - accuracy: 0.8069 - val_loss: 0.9628 - val_accuracy: 0.6888
# Epoch 44/500
# 62/62 [==============================] - 0s 874us/step - loss: 0.5471 - accuracy: 0.8008 - val_loss: 0.9640 - val_accuracy: 0.6983
# Epoch 45/500
# 62/62 [==============================] - 0s 857us/step - loss: 0.5464 - accuracy: 0.8008 - val_loss: 0.9651 - val_accuracy: 0.6936
# Epoch 46/500
# 62/62 [==============================] - 0s 858us/step - loss: 0.5405 - accuracy: 0.7937 - val_loss: 0.9707 - val_accuracy: 0.6912
# Epoch 47/500
# 62/62 [==============================] - 0s 857us/step - loss: 0.5402 - accuracy: 0.7988 - val_loss: 0.9674 - val_accuracy: 0.6888
# Epoch 48/500
# 62/62 [==============================] - 0s 851us/step - loss: 0.5347 - accuracy: 0.7988 - val_loss: 0.9681 - val_accuracy: 0.6936
# Epoch 49/500
# 62/62 [==============================] - 0s 857us/step - loss: 0.5389 - accuracy: 0.7967 - val_loss: 0.9689 - val_accuracy: 0.6912

# %%
model.evaluate(X_test, y_test)
# Out:
# 19/19 [==============================] - 0s 534us/step - loss: 0.9835 - accuracy: 0.6867
# [0.9835186004638672, 0.6866666674613953]

# %%
plot_loss_accuracy(history, title='With Early Stopping includes patience 30')

# %% [markdown]
# 🧑🏻‍🏫 **Remarks**
#
#
# * 📉 The model continues to converge even though its loss function had some consecutive loss increases/decreases w.r.t. to the number of epochs.
#
# * 🤷🏻‍♂️ The `patience` number to select is highly related to the task at hand and there is not any general rule of thumb.
#
# * 🧑🏻‍🏫 If you selected a high patience value for your Early Stopping:
#     * 🤞 Your Neural Net should theoretically still stop training before the end (not always the case if your number of epochs is too low...)
#     * ❗️ Your validation loss will increase again after reaching a minimum value... but ideally, you want it to be as low as possible. The validation loss potentially reaches a minimum for certain weights at a certain epoch.
#         * 🤔 How to collect these weights?
#
# 📚 The Early Stopping criterion enables you to:
# - *stop the convergence*
# - *restore the best weights of the Neural Network when it had the lowest error level (or the best score) on the validation set*, thanks to **`restore_best_weights = True`** (that is set to `False` by default).

# %% [markdown]
# ❓ **Question: restore the best weights of a model** ❓
#
# * Run the model with an Early Stopping criterion that will restore the best weights of the Neural Net
# * Plot the loss and accuracy
# * Print the accuracy on the test set

# %%
es = EarlyStopping(patience=30, restore_best_weights= True)

model = initialize_model()

history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 500,
                    batch_size = 16, 
                    verbose = 1, 
                    callbacks = [es] # This will call the Early Stopping Criterion for each epoch
                   )
# Out:
# Epoch 1/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.0701 - accuracy: 0.1359 - val_loss: 3.6944 - val_accuracy: 0.1188
# Epoch 2/500
# 62/62 [==============================] - 0s 935us/step - loss: 2.8238 - accuracy: 0.1961 - val_loss: 2.4034 - val_accuracy: 0.1900
# Epoch 3/500
# 62/62 [==============================] - 0s 931us/step - loss: 2.1450 - accuracy: 0.2533 - val_loss: 2.0940 - val_accuracy: 0.2494
# Epoch 4/500
# 62/62 [==============================] - 0s 941us/step - loss: 1.9488 - accuracy: 0.3034 - val_loss: 1.9779 - val_accuracy: 0.2898
# Epoch 5/500
# 62/62 [==============================] - 0s 934us/step - loss: 1.8418 - accuracy: 0.3473 - val_loss: 1.8901 - val_accuracy: 0.3112
# Epoch 6/500
# 62/62 [==============================] - 0s 926us/step - loss: 1.7515 - accuracy: 0.3585 - val_loss: 1.8096 - val_accuracy: 0.3515
# Epoch 7/500
# 62/62 [==============================] - 0s 894us/step - loss: 1.6711 - accuracy: 0.3912 - val_loss: 1.7349 - val_accuracy: 0.3800
# Epoch 8/500
# 62/62 [==============================] - 0s 935us/step - loss: 1.5903 - accuracy: 0.4178 - val_loss: 1.6473 - val_accuracy: 0.4133
# Epoch 9/500
# 62/62 [==============================] - 0s 928us/step - loss: 1.4838 - accuracy: 0.4484 - val_loss: 1.5450 - val_accuracy: 0.4204
# Epoch 10/500
# 62/62 [==============================] - 0s 916us/step - loss: 1.3696 - accuracy: 0.4954 - val_loss: 1.4352 - val_accuracy: 0.4774
# Epoch 11/500
# 62/62 [==============================] - 0s 921us/step - loss: 1.2466 - accuracy: 0.5506 - val_loss: 1.3159 - val_accuracy: 0.5368
# Epoch 12/500
# 62/62 [==============================] - 0s 922us/step - loss: 1.1472 - accuracy: 0.5924 - val_loss: 1.2316 - val_accuracy: 0.5914
# Epoch 13/500
# 62/62 [==============================] - 0s 929us/step - loss: 1.0759 - accuracy: 0.6241 - val_loss: 1.1733 - val_accuracy: 0.6128
# Epoch 14/500
# 62/62 [==============================] - 0s 906us/step - loss: 1.0211 - accuracy: 0.6394 - val_loss: 1.1252 - val_accuracy: 0.6413
# Epoch 15/500
# 62/62 [==============================] - 0s 923us/step - loss: 0.9793 - accuracy: 0.6578 - val_loss: 1.0959 - val_accuracy: 0.6485
# Epoch 16/500
# 62/62 [==============================] - 0s 901us/step - loss: 0.9360 - accuracy: 0.6752 - val_loss: 1.0745 - val_accuracy: 0.6508
# Epoch 17/500
# 62/62 [==============================] - 0s 899us/step - loss: 0.9019 - accuracy: 0.6782 - val_loss: 1.0632 - val_accuracy: 0.6580
# Epoch 18/500
# 62/62 [==============================] - 0s 879us/step - loss: 0.8731 - accuracy: 0.6834 - val_loss: 1.0534 - val_accuracy: 0.6698
# Epoch 19/500
# 62/62 [==============================] - 0s 875us/step - loss: 0.8491 - accuracy: 0.6905 - val_loss: 1.0501 - val_accuracy: 0.6627
# Epoch 20/500
# 62/62 [==============================] - 0s 857us/step - loss: 0.8267 - accuracy: 0.6956 - val_loss: 1.0432 - val_accuracy: 0.6698
# Epoch 21/500
# 62/62 [==============================] - 0s 873us/step - loss: 0.8045 - accuracy: 0.7007 - val_loss: 1.0329 - val_accuracy: 0.6603
# Epoch 22/500
# 62/62 [==============================] - 0s 947us/step - loss: 0.7864 - accuracy: 0.7109 - val_loss: 1.0347 - val_accuracy: 0.6722
# Epoch 23/500
# 62/62 [==============================] - 0s 869us/step - loss: 0.7692 - accuracy: 0.7140 - val_loss: 1.0389 - val_accuracy: 0.6698
# Epoch 24/500
# 62/62 [==============================] - 0s 890us/step - loss: 0.7553 - accuracy: 0.7222 - val_loss: 1.0282 - val_accuracy: 0.6698
# Epoch 25/500
# 62/62 [==============================] - 0s 864us/step - loss: 0.7389 - accuracy: 0.7232 - val_loss: 1.0327 - val_accuracy: 0.6817
# Epoch 26/500
# 62/62 [==============================] - 0s 875us/step - loss: 0.7294 - accuracy: 0.7375 - val_loss: 1.0339 - val_accuracy: 0.6722
# Epoch 27/500
# 62/62 [==============================] - 0s 868us/step - loss: 0.7144 - accuracy: 0.7324 - val_loss: 1.0260 - val_accuracy: 0.6793
# Epoch 28/500
# 62/62 [==============================] - 0s 860us/step - loss: 0.7017 - accuracy: 0.7406 - val_loss: 1.0261 - val_accuracy: 0.6722
# Epoch 29/500
# 62/62 [==============================] - 0s 876us/step - loss: 0.6904 - accuracy: 0.7446 - val_loss: 1.0352 - val_accuracy: 0.6722
# Epoch 30/500
# 62/62 [==============================] - 0s 861us/step - loss: 0.6767 - accuracy: 0.7538 - val_loss: 1.0349 - val_accuracy: 0.6651
# Epoch 31/500
# 62/62 [==============================] - 0s 878us/step - loss: 0.6668 - accuracy: 0.7497 - val_loss: 1.0395 - val_accuracy: 0.6722
# Epoch 32/500
# 62/62 [==============================] - 0s 887us/step - loss: 0.6585 - accuracy: 0.7630 - val_loss: 1.0372 - val_accuracy: 0.6722
# Epoch 33/500
# 62/62 [==============================] - 0s 853us/step - loss: 0.6459 - accuracy: 0.7620 - val_loss: 1.0495 - val_accuracy: 0.6698
# Epoch 34/500
# 62/62 [==============================] - 0s 870us/step - loss: 0.6388 - accuracy: 0.7579 - val_loss: 1.0480 - val_accuracy: 0.6651
# Epoch 35/500
# 62/62 [==============================] - 0s 856us/step - loss: 0.6296 - accuracy: 0.7640 - val_loss: 1.0511 - val_accuracy: 0.6556
# Epoch 36/500
# 62/62 [==============================] - 0s 870us/step - loss: 0.6175 - accuracy: 0.7681 - val_loss: 1.0520 - val_accuracy: 0.6532
# Epoch 37/500
# 62/62 [==============================] - 0s 844us/step - loss: 0.6104 - accuracy: 0.7773 - val_loss: 1.0698 - val_accuracy: 0.6603
# Epoch 38/500
# 62/62 [==============================] - 0s 855us/step - loss: 0.6035 - accuracy: 0.7773 - val_loss: 1.0653 - val_accuracy: 0.6580
# Epoch 39/500
# 62/62 [==============================] - 0s 849us/step - loss: 0.5968 - accuracy: 0.7824 - val_loss: 1.0578 - val_accuracy: 0.6651
# Epoch 40/500
# 62/62 [==============================] - 0s 862us/step - loss: 0.5891 - accuracy: 0.7835 - val_loss: 1.0548 - val_accuracy: 0.6627
# Epoch 41/500
# 62/62 [==============================] - 0s 967us/step - loss: 0.5830 - accuracy: 0.7865 - val_loss: 1.0681 - val_accuracy: 0.6698
# Epoch 42/500
# 62/62 [==============================] - 0s 918us/step - loss: 0.5778 - accuracy: 0.7824 - val_loss: 1.0524 - val_accuracy: 0.6556
# Epoch 43/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5737 - accuracy: 0.7926 - val_loss: 1.0679 - val_accuracy: 0.6603
# Epoch 44/500
# 62/62 [==============================] - 0s 962us/step - loss: 0.5711 - accuracy: 0.7865 - val_loss: 1.0661 - val_accuracy: 0.6580
# Epoch 45/500
# 62/62 [==============================] - 0s 977us/step - loss: 0.5635 - accuracy: 0.7886 - val_loss: 1.0752 - val_accuracy: 0.6698
# Epoch 46/500
# 62/62 [==============================] - 0s 997us/step - loss: 0.5598 - accuracy: 0.7886 - val_loss: 1.0597 - val_accuracy: 0.6722
# Epoch 47/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5535 - accuracy: 0.7886 - val_loss: 1.0747 - val_accuracy: 0.6651
# Epoch 48/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5499 - accuracy: 0.7967 - val_loss: 1.0827 - val_accuracy: 0.6698
# Epoch 49/500
# 62/62 [==============================] - 0s 914us/step - loss: 0.5454 - accuracy: 0.7947 - val_loss: 1.0749 - val_accuracy: 0.6651
# Epoch 50/500
# 62/62 [==============================] - 0s 971us/step - loss: 0.5424 - accuracy: 0.7978 - val_loss: 1.0785 - val_accuracy: 0.6603
# Epoch 51/500
# 62/62 [==============================] - 0s 987us/step - loss: 0.5390 - accuracy: 0.7967 - val_loss: 1.1051 - val_accuracy: 0.6580
# Epoch 52/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5315 - accuracy: 0.8039 - val_loss: 1.1000 - val_accuracy: 0.6627
# Epoch 53/500
# 62/62 [==============================] - 0s 1ms/step - loss: 0.5316 - accuracy: 0.8069 - val_loss: 1.0974 - val_accuracy: 0.6722
# Epoch 54/500
# 62/62 [==============================] - 0s 996us/step - loss: 0.5252 - accuracy: 0.8069 - val_loss: 1.1010 - val_accuracy: 0.6770
# Epoch 55/500
# 62/62 [==============================] - 0s 910us/step - loss: 0.5262 - accuracy: 0.8008 - val_loss: 1.1053 - val_accuracy: 0.6627
# Epoch 56/500
# 62/62 [==============================] - 0s 879us/step - loss: 0.5192 - accuracy: 0.8069 - val_loss: 1.1052 - val_accuracy: 0.6675
# Epoch 57/500
# 62/62 [==============================] - 0s 871us/step - loss: 0.5168 - accuracy: 0.8141 - val_loss: 1.1170 - val_accuracy: 0.6793

# %%
model.evaluate(X_test, y_test)
# Out:
# 19/19 [==============================] - 0s 455us/step - loss: 0.9748 - accuracy: 0.6567
# [0.9748335480690002, 0.6566666960716248]

# %%
plot_loss_accuracy(history, title='With Early Stopping patience 30 and restore flag true')

# %% [markdown]
# 🥡 <u>Takeaways from the Early Stopping criterion</u>:
#
# * You can look at the 📚 [**Early Stopping documentation**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) to play with other parameters
#
# *  No longer need to have a look at the number of epochs as long as the model hits the stopping criterion. So, in the future, you should set a large number of epochs and the Early Stopping criterion will take care of stopping the training procedure before the model overfits!

# %% [markdown]
# ### (2.2) Batch-size & Epochs
#
# 🕵️‍♀️ Let's investigate the impact of the batch size on training a Neural Network and how we can use it to control how fast the parameters are updated.

# %% [markdown]
# ❓ **Question: playing with the batch size** ❓
#
# Let's run the previous model with ***different batch sizes*** (with the Early Stopping criterion included) and plot the results.
#
# 👉 Run the following cell

# %%
# %%time
# RUN THIS CELL
es = EarlyStopping(patience=20, restore_best_weights=True)

for batch_size in [1, 4, 32]:
    
    model = initialize_model()

    history = model.fit(X_train, y_train,
                        validation_split = 0.3,
                        epochs = 500,
                        batch_size = batch_size, 
                        verbose = 0, 
                        callbacks = [es])

    results = model.evaluate(X_test, y_test, verbose=0)
    plot_loss_accuracy(history, title=f'------ BATCH SIZE {batch_size} ------\n The accuracy on the test set is of {results[1]:.2f}')
# Out:
# CPU times: user 27.8 s, sys: 8 s, total: 35.8 s
# Wall time: 23.9 s

# %% [markdown]
# ❓ **Question: impact of the batch size on the convergence of a Neural Network** ❓
#
# Look at the oscillations of the accuracy and the loss with respect to the batch size number.
#
# Is this coherent with what we saw when playing with the Tensorflow Playground?

# %% [markdown]
# Yes

# %% [markdown]
# ❓ **Questions about the number of parameters' updates** ❓
#
# * How many optimizations of the weights are done within one epoch (with respect to the number of observations and the batch size)?
# * Does one epoch have more weight updates with a large or a small batch size?

# %% [markdown]
# > with the respect of the number of observations and batch size

# %% [markdown]
# > one epoch have more weight updates with a small batch size

# %% [markdown]
# <details>
#     <summary><i>Explanations</i></summary>
#
#
# ***`BEGIN_EXPLANATIONS`***
#
# Copy-paste this code in a new cell, run it and observe.
#
# ```python
# print(f"There are {X_train.shape[0]} rows in the training set")
#
# batch_size = 16
# epochs = 2
#
# model = initialize_model()
#
# history = model.fit(X_train,
#                     y_train,
#                     validation_split = 0.3,
#                     epochs = epochs,
#                     batch_size = batch_size,
#                     verbose = 1)
# ```
#
#
# <u><b><i>Number of parameters' updates:</i></b></u>
#
# * There are 1400 rows in the training set:
#     * $ 70 \% \times 1400 = 980 $ rows are used as the train set within the training set
#     * $ 30 \% \times 1400 = 420 $ rows are used as the validation set
#
# * For each epoch, we run a forward/backward propagation $ \large \lceil \frac{980}{batch size} \rceil = \lceil \frac{980}{16}\rceil = 62$ times
#
# * Without the Early Stopping Criterion, we will have - overall - _number of_ $ epochs \times 62 = 2 \times 62 = 124 $ iterations
#
# <u><b><i>Impact of the batch size:</i></b></u>
#
# The smaller the batch size
#
# $ \implies $ The more sub-iterations will be done
#
# $ \implies $ Parameters will be updated more frequently
#
# $ \implies $ We may need less epochs
#
# _(but we also don't care too much about the number of epochs if we use an Early Stopping Criterion with patience anyway)_
#
# ***`END_EXPLANATIONS`***
#
# </details>

# %%
batch_size = 16
epochs = 2

model = initialize_model()

history = model.fit(X_train, 
                    y_train,
                    validation_split = 0.3,
                    epochs = epochs,
                    batch_size = batch_size, 
                    verbose = 1)
# Out:
# Epoch 1/2
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7894 - accuracy: 0.1788 - val_loss: 2.6104 - val_accuracy: 0.2708
# Epoch 2/2
# 62/62 [==============================] - 0s 906us/step - loss: 2.2519 - accuracy: 0.2921 - val_loss: 1.9193 - val_accuracy: 0.3634

# %% [markdown]
# ### (2.3) Regularization

# %% [markdown]
# ❗️ ***Neural Networks with complex architectures can quickly lead to overfitting*** (_"too many" layers and/or neurons..._). ❗️
#
# 🔥 But as Dense Neural Networks are just activated linear regressions, the weights can be constrained using L1, L2 or L1-L2 penalties!
#
#
# 🚓 So, let's apply some L2 or L1 penalties to these neurons. As in Machine Learning, these penalties are called ***`Regularizers`***.
#
#
#
# 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/regularizers">**tensorflow/keras/regularizers**</a>

# %% [markdown]
# ❓ **Initial Question: observing overfitting one more time before regularizing...**❓
#
# * First, let's initialize a model that has too many parameters for the task such that it overfits the training data quickly. _To that purpose, let's not use any Early Stopping criterion._
#
# 🎁 Let's not waste time re-coding something that you are now used to, just run the following cell and observe what is happening 👇

# %%
# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 3. Training 
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
                    batch_size = 16, 
                    verbose=0)

# 4. Evaluation
results_train = model.evaluate(X_train, y_train, verbose = 0)
results_test = model.evaluate(X_test, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the test set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the test set is 0.64...
# ...whereas the accuracy on the training set is 0.85!

# %% [markdown]
# ☝️ In our *over-parametrized network*, ***some neurons became too specific to the given training data***, preventing the network from generalizing to new data.
#
# 😕 This led to some overfitting...!

# %% [markdown]
# ❓ **Question: studying the impact of regularization on the Neural Net**❓
#
# * Change the previous code to integrate a L2 or L1 regularizer to your Dense Layers.

# %%
from tensorflow.keras import regularizers

# %%
#regularizer

reg_l1 = regularizers.L1(0.1)

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10, kernel_regularizer = reg_l1))
model.add(layers.Dense(10, activation='relu', activity_regularizer = reg_l1))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 3. Training 
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
                    batch_size = 16, 
                    verbose=0)

# 4. Evaluation
results_train = model.evaluate(X_train, y_train, verbose = 0)
results_test = model.evaluate(X_test, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the test set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the test set is 0.65...
# ...whereas the accuracy on the training set is 0.71!

# %% [markdown]
# ### (2.4) Dropout layers

# %% [markdown]
# ✂️ **`Dropout Layers`** ✂️
#
# - ✅ They are super straightforward to code
# - 👩🏻‍🏫 But what is going on _"under the hood"_ ? (You love this expression right? 😏)
#
# <u><i>Introduction to Dropout Layers</i><u>
#
# * Their role is to randomly cancel the output of some neurons during the training phase
# * It prevents the network from getting too specific to the input data. With Dropout layers,
#     - No neuron can overspecialize in learning a pattern of the dataset because its output is sometimes canceled by the Dropout Layer
#     - Overall, a Dropout Layer forces the information of an input to be spread across multiple neurons instead of only one specific neuron
#
# <details>
#     <summary><i>[optional reading] Untoggle this for further explanations about Dropout Layers</i></summary>
#
# 🤔 Remember what we said about ***neurons becoming too specific***?
#
# **`BEGIN_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
#
# ---
#
# ⚽️ *An analogy with football:*
#
# Think about a football team. There are 11 players on the pitch, but there are also players on the bench, what for ?
# * The coach may want to substitute injured or tired players during the game
# * The team may be:
#     - losing the game and willing to replace a midfielder with a more ***versatile player*** who can be more offensive (= ***mix of*** midfielder/attacker role)
#     - winning the game and would like to secure the result by replacing a midfielder with a more ***versatile player*** who can be more defensive ( = ***mix of*** midfielder/defense role)
#
# 💡 Well, in a Neural Net, there is also a risk that a neuron over-specializes in detecting one pattern, whereas it would be more advisable to keep it more versatile.
#
# ---
#
# 📚 **The goal of [Dropout layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) is to prevent neurons from over-specializing**.
#
# 🧑🏻‍🏫 How do Dropout layers work?
#
# * 👉 When we apply a **Dropout rate** of 20% to a layer $k$, 20% of the ***selected neurons*** will have their ***weights temporarily set to 0*** , which has the following consequences:
#     1. A neuron computed at layer $k+1$ considers all the weights as usual, but since some of them were temporarily set to 0, they were “ignored” while creating the neurons of this layer $k+1$
#     2. Once a batch of data points have been seen by the Neural Network (**forward propagation**) and 80% of the weights in a layer optimized/updated (**backward propagation** with the **adam** optimizer), the Neural Network moves on to the forward propagation of the next batch, where it will use:
#         * 80% of the weights, those which were updated
#         * 20% of weights, those which were previously ignored (which kept their original values and were actually not set in stone to 0 but just temporarily)
#         * Based on these weights, we will again go through this Dropout Layer which again is going to ignore 20% of the weights of a given layer temporarily. Be careful, the selection of these 20% being random, the weights which will be ignored this time won't necessarily be the same weights as before!
#
# * 👉 Think about the ***Dropout Rate*** as a ***sampling with replacement***
#
# * 👉 By ***randomly shutting down*** different neurons at different epochs, we ***force the datapoints*** to be analyzed by different neurons. At the end of the day, these neurons will become ***more versatile*** instead of overspecializing!
#
# **`END_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
#
# </details>
#
# ---

# %% [markdown]
# ❓ **Question: studying the impact of Dropout layers on the Neural Net**❓
#
# * Include some Dropout layers in the architecture of your original model.
# _(Don't add regularizers here)_
#
# * What can you observe about the convergence of your model? What about its ability to generalize?

# %%
# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dropout(rate=0.15))

model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dropout(rate=0.1))

model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 3. Training 
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
                    batch_size = 16, 
                    verbose=0)

# 4. Evaluation
results_train = model.evaluate(X_train, y_train, verbose = 0)
results_test = model.evaluate(X_test, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the test set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the test set is 0.68...
# ...whereas the accuracy on the training set is 0.79!

# %% [markdown]
# <u><b>Conclusions:</b></u>
#
# * ❗️ If you train a Neural Network too much (too many layers, too many neurons and/or too many epochs), it will overfit very quickly
#
# * 🥊 To prevent overfitting in Deep Learning, you can use Early Stopping, Regularization and Dropout Layers.
#
# * ❗️ Be careful, if you use these techniques, you might end up on the other spectrum of the performance where you model would underfit the dataset!
#
# * 🆗 You could potentially look at the batch size but we usually use 16 or 32. And as the French Computer Scientist [**Yann Lecun**](https://en.wikipedia.org/wiki/Yann_LeCun) said (Facebook x NYU):
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/deep_learning_yann_lecun_batch_size.png" alt="batch_size_yann_lecun" width="400" height="250">

# %% [markdown]
# 🏁 Congratulations!
#
# 💾 Do not forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move to the next challenge!
